# %% [markdown]
# #### spaCy - Setup

# %%
# %%writefile req.txt
# spacy[lookups,ja,th]~=3.0
# regex==2020.11.13
# emoji==1.2.0
# pymorphy2==0.9.1
# pymorphy2-dicts-ru==2.4.417127.4579844
# pymorphy2-dicts-uk==2.4.1.1.1460299261
# pyvi==0.1
# jieba==0.42.1
# fastcore==1.3.19
# Out:
# Writing req.txt

# %%
# !pip install -r -q req.txt

# %%
# Use ontology tagging sentence splitter
# !git clone https://github.com/dataiku/dss-plugin-nlp-analysis.git
# %cd dss-plugin-nlp-analysis/python-lib/

# %%
from nlp.sentence_splitter import SentenceSplitter
from nlp.spacy_tokenizer import MultilingualTokenizer
from spacy.pipeline.sentencizer import Sentencizer

import pandas as pd

text_df = pd.DataFrame(["hello there! My name is Dr. No. I am a Doctor."], columns=["text"])
text_df = pd.DataFrame(["Bonjour! Je m'appelle Dr. No et je suis un docteur."], columns=["text"])
text_df = pd.DataFrame(["こんにちは。私は海がすきです！海も好きですか？"], columns=["text"])
text_df = pd.DataFrame(["మీరు ఎలా ఉన్నారు? మీరు ఎలా ఉన్నారు?"], columns=["text"])

config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }

tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )


languages = ["en", "fr", "ja", "te"]
for language in languages:
    tokenizer.add_spacy_tokenizer(language)


text_column = "text"

sentence_splitter = SentenceSplitter(
            text_df=text_df,
            text_column=text_column,
            tokenizer=tokenizer,
            language=languages[3],
            language_column=None)

# %%
out = sentence_splitter.split_sentences_df()
out[0].head()
# Out:
#                                   text                          list_sentences
# 0  మీరు ఎలా ఉన్నారు? మీరు ఎలా ఉన్నారు?  [మీరు ఎలా ఉన్నారు?, మీరు ఎలా ఉన్నారు?]

# %% [markdown]
# #### PySBD - Setup

# %%
# !pip install -q pysbd
# Out:
#      |████████████████████████████████| 71 kB 3.2 MB/s

# %%
import pysbd
text = "My name is Jonas E. Smith. Please turn to p. 55."
seg = pysbd.Segmenter(language="en", clean=False)
print(seg.segment(text))
# Out:
# ['My name is Jonas E. Smith. ', 'Please turn to p. 55.']

# %%
text = "こんにちは。私は海がすきです！海も好きですか？"

seg = pysbd.Segmenter(language="en", clean=False)
print(seg.segment(text))
# Out:
# ['こんにちは。', '私は海がすきです！', '海も好きですか？']

# %%
text = "한국어(韓國語)는 대한민국과 조선민주주의인민공화국의 공용어로, 대한민국에서는 한국어 또는 한국말이라고 부르고, 조선민주주의인민공화국에서는 조선어(朝鮮語) 또는 조선말이라고 부른다. 한국과 북한에 비해서 인구는 적지만 중국 옌볜 조선족 자치주도 사용한다. 해외 이주에 의해 일본, 미국, 중화인민공화국, 러시아, 우즈베키스탄, 캐나다, 오스트레일리아, 필리핀, 베트남 등 세계 여러 지역에 한민족 인구가 거주하게 되면서 전세계 각지에서 한국어가 사용 되고 있다. 2016년 1월 초 기준으로 한국어 사용 인구는 거의 대부분이 대한민국과 조선민주주의인민공화국에 거주중이며 약 8000만 명으로 추산된다.[1]"

seg = pysbd.Segmenter(language="en", clean=False)
seg.segment(text)
# Out:
# ['한국어(韓國語)는 대한민국과 조선민주주의인민공화국의 공용어로, 대한민국에서는 한국어 또는 한국말이라고 부르고, 조선민주주의인민공화국에서는 조선어(朝鮮語) 또는 조선말이라고 부른다. ',
#  '한국과 북한에 비해서 인구는 적지만 중국 옌볜 조선족 자치주도 사용한다. ',
#  '해외 이주에 의해 일본, 미국, 중화인민공화국, 러시아, 우즈베키스탄, 캐나다, 오스트레일리아, 필리핀, 베트남 등 세계 여러 지역에 한민족 인구가 거주하게 되면서 전세계 각지에서 한국어가 사용 되고 있다. ',
#  '2016년 1월 초 기준으로 한국어 사용 인구는 거의 대부분이 대한민국과 조선민주주의인민공화국에 거주중이며 약 8000만 명으로 추산된다.',
#  '[1]']

# %%
seg = pysbd.Segmenter(language="zh", clean=False)
seg.segment(text)
# Out:
# ['한국어(韓國語)는 대한민국과 조선민주주의인민공화국의 공용어로, 대한민국에서는 한국어 또는 한국말이라고 부르고, 조선민주주의인민공화국에서는 조선어(朝鮮語) 또는 조선말이라고 부른다. ',
#  '한국과 북한에 비해서 인구는 적지만 중국 옌볜 조선족 자치주도 사용한다. ',
#  '해외 이주에 의해 일본, 미국, 중화인민공화국, 러시아, 우즈베키스탄, 캐나다, 오스트레일리아, 필리핀, 베트남 등 세계 여러 지역에 한민족 인구가 거주하게 되면서 전세계 각지에서 한국어가 사용 되고 있다. ',
#  '2016년 1월 초 기준으로 한국어 사용 인구는 거의 대부분이 대한민국과 조선민주주의인민공화국에 거주중이며 약 8000만 명으로 추산된다.',
#  '[1]']

# %% [markdown]
# #### PySBD vs spaCy

# %% [markdown]
# ##### Catalan

# %%
# Catalan only in spaCy but not in PySBD
# > Choose Spanish for PySBD

# https://ca.wikipedia.org/wiki/Catal%C3%A0
ca_text = """
El català (denominació oficial a Catalunya, a les Illes Balears, a Andorra, a la ciutat de l'Alguer i tradicional a Catalunya Nord) o valencià (denominació oficial al País Valencià i tradicional al Carxe) és una llengua romànica parlada a Catalunya, el País Valencià (tret d'algunes comarques i localitats de l'interior), les Illes Balears, Andorra, la Franja de Ponent (a l'Aragó), la ciutat de l'Alguer (a l'illa de Sardenya), la Catalunya del Nord,[8] el Carxe (un petit territori de Múrcia poblat per immigrats valencians),[9][10] i en comunitats arreu del món (entre les quals destaca la de l'Argentina, amb 198.000 parlants).[11] Té deu milions de parlants, dels quals quasi la meitat ho són de llengua materna; el seu domini lingüístic, amb una superfície de 68.730 km² i 13.529.127 d'habitants (2009),[12] inclou 1.687 termes municipals. Com a llengua materna, és parlada per quatre milions de persones (29% de la població del territori lingüístic), de les quals 2.263.000 a Catalunya,[13] 1.521.000 al País Valencià[14] i 417.000 a les Illes Balears.[15] Com les altres llengües romàniques, el català prové del llatí vulgar que parlaven els romans que s'establiren a Hispània durant l'edat antiga.
"""
x = time.time()
# PYSBD
seg = pysbd.Segmenter(language="es", clean=False)

print("PySBD")
for i in seg.segment(ca_text):
  print(i)

y = time.time()
print("TIME:", y - x)

# SPACY
config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }
tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )
tokenizer.add_spacy_tokenizer("ca")
sentence_splitter = SentenceSplitter(
            text_df=pd.DataFrame([ca_text], columns=["text"]),
            text_column="text",
            tokenizer=tokenizer,
            language="ca",
            language_column=None)


print("-"*50)
out = sentence_splitter.split_sentences_df()[0].list_sentences.values.tolist()[0]
print("\nspaCy")
for i in out:
  print(i)


print("TIME:", time.time() - y)
# Out:
# PySBD
# El català (denominació oficial a Catalunya, a les Illes Balears, a Andorra, a la ciutat de l'Alguer i tradicional a Catalunya Nord) o valencià (denominació oficial al País Valencià i tradicional al Carxe) és una llengua romànica parlada a Catalunya, el País Valencià (tret d'algunes comarques i localitats de l'interior), les Illes Balears, Andorra, la Franja de Ponent (a l'Aragó), la ciutat de l'Alguer (a l'illa de Sardenya), la Catalunya del Nord,[8] el Carxe (un petit territori de Múrcia poblat per immigrats valencians),[9][10] i en comunitats arreu del món (entre les quals destaca la de l'Argentina, amb 198.000 parlants).[11]
# Té deu milions de parlants, dels quals quasi la meitat ho són de llengua materna; el seu domini lingüístic, amb una superfície de 68.730 km² i 13.529.127 d'habitants (2009),[12] inclou 1.687 termes municipals.
# Com a llengua materna, és parlada per quatre milions de persones (29% de la població del territori lingüístic), de les quals 2.263.000 a Catalunya,[13] 1.521.000 al País Valencià[14] i 417.000 a les Illes Balears.[15]
# Com les altres llengües romàniques, el català prové del llatí vulgar que parlaven els romans que s'establiren a Hispània durant l'edat antiga.
#
# TIME: 0.013701200485229492
# --------------------------------------------------
# 100%|██████████| 1/1 [00:00<00:00, 96.13it/s]
# spaCy
# El català (denominació oficial a Catalunya, a les Illes Balears, a Andorra, a la ciutat de l'Alguer i tradicional a Catalunya Nord) o valencià (denominació oficial al País Valencià i tradicional al Carxe) és una llengua romànica parlada a Catalunya, el País Valencià (tret d'algunes comarques i localitats de l'interior), les Illes Balears, Andorra, la Franja de Ponent (a l'Aragó), la ciutat de l'Alguer (a l'illa de Sardenya), la Catalunya del Nord,[8] el Carxe (un petit territori de Múrcia poblat per immigrats valencians),[9][10] i en comunitats arreu del món (entre les quals destaca la de l'Argentina, amb 198.000 parlants).[11] Té deu milions de parlants, dels quals quasi la meitat ho són de llengua materna; el seu domini lingüístic, amb una superfície de 68.730 km² i 13.529.127 d'habitants (2009),[12] inclou 1.687 termes municipals.
# Com a llengua materna, és parlada per quatre milions de persones (29% de la població del territori lingüístic), de les quals 2.263.000 a Catalunya,[13] 1.521.000 al País Valencià[14] i 417.000 a les Illes Balears.[15] Com les altres llengües romàniques, el català prové del llatí vulgar que parlaven els romans que s'establiren a Hispània durant l'edat antiga.
# TIME: 0.13249540328979492

# %% [markdown]
# spaCy does not catch a couple due to brackets - pySBD is better here.

# %% [markdown]
# ##### Thai

# %%
# Thai
# Not in PySBD > Use Chinese instead

# https://th.wikipedia.org/wiki/%E0%B8%9B%E0%B8%B1%E0%B8%8D%E0%B8%8D%E0%B8%B2%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%94%E0%B8%B4%E0%B8%A9%E0%B8%90%E0%B9%8C
th_text = """
แนวคิดเรื่องเครื่องจักรที่คิดได้และสิ่งมีชีวิตเทียมนั้นมีมาตั้งแต่สมัยกรีกโบราณ เช่นหุ่นยนต์ทาลอสแห่งครีต อันเป็นหุ่นยนต์ทองแดงของเทพฮิฟีสตัส แหล่งอารยธรรมใหญ่ ๆ ของโลกมักจะเชื่อเรื่องหุ่นยนต์ที่มีความคล้ายกับมนุษย์ เช่น ในอียิปต์และกรีซ ต่อมา ช่วงกลางศตวรรษที่ 19 และ 20 สิ่งมีชีวิตเทียมเริ่มปรากฏอย่างแพร่หลายในนิยายวิทยาศาสตร์ เช่น แฟรงเกนสไตน์ของแมรี เชลลีย์ หรือ R.U.R.ของกาเรล ชาเปก แนวคิดเหล่านี้ผ่านการอภิปรายมาอย่างแพร่หลาย โดยเฉพาะในแง่ของความหวัง ความกลัว หรือความกังวลด้านศีลธรรมเนื่องจากการมีอยู่ของปัญญาประดิษฐ์

กลไกหรือการให้เหตุผลอย่างมีแบบแผน ได้รับการพัฒนาขึ้นโดยนักปรัชญาและนักวิทยาศาสตร์มาตั้งแต่สมัยโบราณ การศึกษาด้านตรรกศาสตร์นำไปสู่การคิดค้นเครื่องคำนวณอิเล็กทรอนิกส์ดิจิทัลที่โปรแกรมได้โดยอาศัยหลักการทางคณิตศาสตร์ของแอลัน ทัวริงและคนอื่น ๆ ทฤษฎีการคำนวณของทัวริงชี้ว่า เครื่องจักรที่รู้จักการสลับตัวเลขระหว่าง 0 กับ 1 สามารถเข้าใจนิรนัยทางคณิตศาสตร์ได้ หลังจากนั้น การค้นพบทางด้านประสาทวิทยา ทฤษฎีสารสนเทศ และไซเบอร์เนติกส์ รวมทั้งทฤษฎีการคำนวณของทัวริง ได้ทำให้นักวิทยาศาสตร์บางกลุ่มเริ่มสนใจพิจารณาความเป็นไปได้ของการสร้าง สมองอิเล็กทรอนิกส์ ขึ้นมาอย่างจริงจัง

สาขาปัญญาประดิษฐ์นั้นเริ่มก่อตั้งขึ้นในที่ประชุมวิชาการที่วิทยาลัยดาร์ตมัธ สหรัฐอเมริกาในช่วงหน้าร้อน ค.ศ. 1956[2] โดยผู้ร่วมในการประชุมครั้งนั้น ได้แก่ จอห์น แม็กคาร์ธีย์ มาร์วิน มินสกี อัลเลน นิวเวลล์ อาเธอร์ ซามูเอล และเฮอร์เบิร์ต ไซมอน ที่ได้กลายมาเป็นผู้นำทางสาขาปัญญาประดิษฐ์ในอีกหลายสิบปีต่อมา นักวิทยาศาสตร์และนักศึกษาของพวกเขาเหล่านี้เขียนโปรแกรมที่หลายคนทึ่ง ไม่ว่าจะเป็น คอมพิวเตอร์ที่สามารถเอาชนะคนเล่นหมากรุก แก้ไขปัญหาเกี่ยวกับคำด้วยพีชคณิต พิสูจน์ทฤษฎีทางตรรกวิทยา หรือแม้กระทั่งพูดภาษาอังกฤษได้ ผู้ก่อตั้งสาขาปัญญาประดิษฐ์กลุ่มนี้เชื่อมั่นในอนาคตของเทคโนโลยีใหม่นี้มาก โดยเฮอร์เบิร์ต ไซมอนคาดว่าจะมีเครื่องจักรที่สามารถทำงานทุกอย่างได้เหมือนมนุษย์ภายใน 20 ปีข้างหน้า และมาร์วิน มินสกีก็เห็นพ้องโดยการเขียนว่า "เพียงชั่วอายุคน ปัญหาของการสร้างความฉลาดเทียมจะถูกแก้ไขอย่างยั่งยืน
"""

x = time.time()
# PYSBD
seg = pysbd.Segmenter(language="zh", clean=False)

print("PySBD")
for i in seg.segment(th_text):
  print(i)

y = time.time()
print("TIME:", y - x)

# SPACY - Errors out for Korean as not supported, so it doesnt seem like just because its listed 
config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }
tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )
tokenizer.add_spacy_tokenizer("th")
sentence_splitter = SentenceSplitter(
            text_df=pd.DataFrame([th_text], columns=["text"]),
            text_column="text",
            tokenizer=tokenizer,
            language="th",
            language_column=None)


print("-"*50)
out = sentence_splitter.split_sentences_df()[0].list_sentences.values.tolist()[0]

print("\nspaCy")
for i in out:
  print(i)


print("TIME:", time.time() - y)
# Out:
# PySBD
# แนวคิดเรื่องเครื่องจักรที่คิดได้และสิ่งมีชีวิตเทียมนั้นมีมาตั้งแต่สมัยกรีกโบราณ เช่นหุ่นยนต์ทาลอสแห่งครีต อันเป็นหุ่นยนต์ทองแดงของเทพฮิฟีสตัส แหล่งอารยธรรมใหญ่ ๆ ของโลกมักจะเชื่อเรื่องหุ่นยนต์ที่มีความคล้ายกับมนุษย์ เช่น ในอียิปต์และกรีซ ต่อมา ช่วงกลางศตวรรษที่ 19 และ 20 สิ่งมีชีวิตเทียมเริ่มปรากฏอย่างแพร่หลายในนิยายวิทยาศาสตร์ เช่น แฟรงเกนสไตน์ของแมรี เชลลีย์ หรือ R.U.R.ของกาเรล ชาเปก แนวคิดเหล่านี้ผ่านการอภิปรายมาอย่างแพร่หลาย โดยเฉพาะในแง่ของความหวัง ความกลัว หรือความกังวลด้านศีลธรรมเนื่องจากการมีอยู่ของปัญญาประดิษฐ์
#
#
# กลไกหรือการให้เหตุผลอย่างมีแบบแผน ได้รับการพัฒนาขึ้นโดยนักปรัชญาและนักวิทยาศาสตร์มาตั้งแต่สมัยโบราณ การศึกษาด้านตรรกศาสตร์นำไปสู่การคิดค้นเครื่องคำนวณอิเล็กทรอนิกส์ดิจิทัลที่โปรแกรมได้โดยอาศัยหลักการทางคณิตศาสตร์ของแอลัน ทัวริงและคนอื่น ๆ ทฤษฎีการคำนวณของทัวริงชี้ว่า เครื่องจักรที่รู้จักการสลับตัวเลขระหว่าง 0 กับ 1 สามารถเข้าใจนิรนัยทางคณิตศาสตร์ได้ หลังจากนั้น การค้นพบทางด้านประสาทวิทยา ทฤษฎีสารสนเทศ และไซเบอร์เนติกส์ รวมทั้งทฤษฎีการคำนวณของทัวริง ได้ทำให้นักวิทยาศาสตร์บางกลุ่มเริ่มสนใจพิจารณาความเป็นไปได้ของการสร้าง สมองอิเล็กทรอนิกส์ ขึ้นมาอย่างจริงจัง
#
#
# สาขาปัญญาประดิษฐ์นั้นเริ่มก่อตั้งขึ้นในที่ประชุมวิชาการที่วิทยาลัยดาร์ตมัธ สหรัฐอเมริกาในช่วงหน้าร้อน ค.
# ศ.
# 1956[2] โดยผู้ร่วมในการประชุมครั้งนั้น ได้แก่ จอห์น แม็กคาร์ธีย์ มาร์วิน มินสกี อัลเลน นิวเวลล์ อาเธอร์ ซามูเอล และเฮอร์เบิร์ต ไซมอน ที่ได้กลายมาเป็นผู้นำทางสาขาปัญญาประดิษฐ์ในอีกหลายสิบปีต่อมา นักวิทยาศาสตร์และนักศึกษาของพวกเขาเหล่านี้เขียนโปรแกรมที่หลายคนทึ่ง ไม่ว่าจะเป็น คอมพิวเตอร์ที่สามารถเอาชนะคนเล่นหมากรุก แก้ไขปัญหาเกี่ยวกับคำด้วยพีชคณิต พิสูจน์ทฤษฎีทางตรรกวิทยา หรือแม้กระทั่งพูดภาษาอังกฤษได้ ผู้ก่อตั้งสาขาปัญญาประดิษฐ์กลุ่มนี้เชื่อมั่นในอนาคตของเทคโนโลยีใหม่นี้มาก โดยเฮอร์เบิร์ต ไซมอนคาดว่าจะมีเครื่องจักรที่สามารถทำงานทุกอย่างได้เหมือนมนุษย์ภายใน 20 ปีข้างหน้า และมาร์วิน มินสกีก็เห็นพ้องโดยการเขียนว่า "เพียงชั่วอายุคน ปัญหาของการสร้างความฉลาดเทียมจะถูกแก้ไขอย่างยั่งยืน
#
# TIME: 0.005685091018676758
# --------------------------------------------------
# 100%|██████████| 1/1 [00:00<00:00, 41.36it/s]
# spaCy
# แนวคิดเรื่องเครื่องจักรที่คิดได้และสิ่งมีชีวิตเทียมนั้นมีมาตั้งแต่สมัยกรีกโบราณ เช่นหุ่นยนต์ทาลอสแห่งครีต อันเป็นหุ่นยนต์ทองแดงของเทพฮิฟีสตัส แหล่งอารยธรรมใหญ่ ๆ ของโลกมักจะเชื่อเรื่องหุ่นยนต์ที่มีความคล้ายกับมนุษย์ เช่น ในอียิปต์และกรีซ ต่อมา ช่วงกลางศตวรรษที่ 19 และ 20 สิ่งมีชีวิตเทียมเริ่มปรากฏอย่างแพร่หลายในนิยายวิทยาศาสตร์ เช่น แฟรงเกนสไตน์ของแมรี เชลลีย์ หรือ R.
# U.
# R.
# ของกาเรล ชาเปก แนวคิดเหล่านี้ผ่านการอภิปรายมาอย่างแพร่หลาย โดยเฉพาะในแง่ของความหวัง ความกลัว หรือความกังวลด้านศีลธรรมเนื่องจากการมีอยู่ของปัญญาประดิษฐ์
#
# กลไกหรือการให้เหตุผลอย่างมีแบบแผน ได้รับการพัฒนาขึ้นโดยนักปรัชญาและนักวิทยาศาสตร์มาตั้งแต่สมัยโบราณ การศึกษาด้านตรรกศาสตร์นำไปสู่การคิดค้นเครื่องคำนวณอิเล็กทรอนิกส์ดิจิทัลที่โปรแกรมได้โดยอาศัยหลักการทางคณิตศาสตร์ของแอลัน ทัวริงและคนอื่น ๆ ทฤษฎีการคำนวณของทัวริงชี้ว่า เครื่องจักรที่รู้จักการสลับตัวเลขระหว่าง 0 กับ 1 สามารถเข้าใจนิรนัยทางคณิตศาสตร์ได้ หลังจากนั้น การค้นพบทางด้านประสาทวิทยา ทฤษฎีสารสนเทศ และไซเบอร์เนติกส์ รวมทั้งทฤษฎีการคำนวณของทัวริง ได้ทำให้นักวิทยาศาสตร์บางกลุ่มเริ่มสนใจพิจารณาความเป็นไปได้ของการสร้าง สมองอิเล็กทรอนิกส์ ขึ้นมาอย่างจริงจัง
#
# สาขาปัญญาประดิษฐ์นั้นเริ่มก่อตั้งขึ้นในที่ประชุมวิชาการที่วิทยาลัยดาร์ตมัธ สหรัฐอเมริกาในช่วงหน้าร้อน ค.ศ. 1956[2] โดยผู้ร่วมในการประชุมครั้งนั้น ได้แก่ จอห์น แม็กคาร์ธีย์ มาร์วิน มินสกี อัลเลน นิวเวลล์ อาเธอร์ ซามูเอล และเฮอร์เบิร์ต ไซมอน ที่ได้กลายมาเป็นผู้นำทางสาขาปัญญาประดิษฐ์ในอีกหลายสิบปีต่อมา นักวิทยาศาสตร์และนักศึกษาของพวกเขาเหล่านี้เขียนโปรแกรมที่หลายคนทึ่ง ไม่ว่าจะเป็น คอมพิวเตอร์ที่สามารถเอาชนะคนเล่นหมากรุก แก้ไขปัญหาเกี่ยวกับคำด้วยพีชคณิต พิสูจน์ทฤษฎีทางตรรกวิทยา หรือแม้กระทั่งพูดภาษาอังกฤษได้ ผู้ก่อตั้งสาขาปัญญาประดิษฐ์กลุ่มนี้เชื่อมั่นในอนาคตของเทคโนโลยีใหม่นี้มาก โดยเฮอร์เบิร์ต ไซมอนคาดว่าจะมีเครื่องจักรที่สามารถทำงานทุกอย่างได้เหมือนมนุษย์ภายใน 20 ปีข้างหน้า และมาร์วิน มินสกีก็เห็นพ้องโดยการเขียนว่า "เพียงชั่วอายุคน ปัญหาของการสร้างความฉลาดเทียมจะถูกแก้ไขอย่างยั่งยืน
# TIME: 0.07118892669677734

# %%
th_text = """
แนวคิดเรื่องเครื่องจักรที่คิดได้และสิ่งมีชีวิตเทียมนั้นมีมาตั้งแต่สมัยกรีกโบราณ เช่นหุ่นยนต์ทาลอสแห่งครีต อันเป็นหุ่นยนต์ทองแดงของเทพฮิฟีสตัส แหล่งอารยธรรมใหญ่ ๆ ของโลกมักจะเชื่อเรื่องหุ่นยนต์ที่มีความคล้ายกับมนุษย์ เช่น ในอียิปต์และกรีซ ต่อมา ช่วงกลางศตวรรษที่ 19 และ 20 สิ่งมีชีวิตเทียมเริ่มปรากฏอย่างแพร่หลายในนิยายวิทยาศาสตร์ เช่น แฟรงเกนสไตน์ของแมรี เชลลีย์ หรือ R.U.R.ของกาเรล ชาเปก แนวคิดเหล่านี้ผ่านการอภิปรายมาอย่างแพร่หลาย โดยเฉพาะในแง่ของความหวัง ความกลัว หรือความกังวลด้านศีลธรรมเนื่องจากการมีอยู่ของปัญญาประดิษฐ์

กลไกหรือการให้เหตุผลอย่างมีแบบแผน ได้รับการพัฒนาขึ้นโดยนักปรัชญาและนักวิทยาศาสตร์มาตั้งแต่สมัยโบราณ การศึกษาด้านตรรกศาสตร์นำไปสู่การคิดค้นเครื่องคำนวณอิเล็กทรอนิกส์ดิจิทัลที่โปรแกรมได้โดยอาศัยหลักการทางคณิตศาสตร์ของแอลัน ทัวริงและคนอื่น ๆ ทฤษฎีการคำนวณของทัวริงชี้ว่า เครื่องจักรที่รู้จักการสลับตัวเลขระหว่าง 0 กับ 1 สามารถเข้าใจนิรนัยทางคณิตศาสตร์ได้ หลังจากนั้น การค้นพบทางด้านประสาทวิทยา ทฤษฎีสารสนเทศ และไซเบอร์เนติกส์ รวมทั้งทฤษฎีการคำนวณของทัวริง ได้ทำให้นักวิทยาศาสตร์บางกลุ่มเริ่มสนใจพิจารณาความเป็นไปได้ของการสร้าง สมองอิเล็กทรอนิกส์ ขึ้นมาอย่างจริงจัง

สาขาปัญญาประดิษฐ์นั้นเริ่มก่อตั้งขึ้นในที่ประชุมวิชาการที่วิทยาลัยดาร์ตมัธ สหรัฐอเมริกาในช่วงหน้าร้อน ค.ศ. 1956[2] โดยผู้ร่วมในการประชุมครั้งนั้น ได้แก่ จอห์น แม็กคาร์ธีย์ มาร์วิน มินสกี อัลเลน นิวเวลล์ อาเธอร์ ซามูเอล และเฮอร์เบิร์ต ไซมอน ที่ได้กลายมาเป็นผู้นำทางสาขาปัญญาประดิษฐ์ในอีกหลายสิบปีต่อมา นักวิทยาศาสตร์และนักศึกษาของพวกเขาเหล่านี้เขียนโปรแกรมที่หลายคนทึ่ง ไม่ว่าจะเป็น คอมพิวเตอร์ที่สามารถเอาชนะคนเล่นหมากรุก แก้ไขปัญหาเกี่ยวกับคำด้วยพีชคณิต พิสูจน์ทฤษฎีทางตรรกวิทยา หรือแม้กระทั่งพูดภาษาอังกฤษได้ ผู้ก่อตั้งสาขาปัญญาประดิษฐ์กลุ่มนี้เชื่อมั่นในอนาคตของเทคโนโลยีใหม่นี้มาก โดยเฮอร์เบิร์ต ไซมอนคาดว่าจะมีเครื่องจักรที่สามารถทำงานทุกอย่างได้เหมือนมนุษย์ภายใน 20 ปีข้างหน้า และมาร์วิน มินสกีก็เห็นพ้องโดยการเขียนว่า "เพียงชั่วอายุคน ปัญหาของการสร้างความฉลาดเทียมจะถูกแก้ไขอย่างยั่งยืน
"""
import time
x = time.time()
# PYSBD
seg = pysbd.Segmenter(language="my", clean=False)

print("PySBD")
for i in seg.segment(th_text):
  print(i)

y = time.time()
print("TIME:", y - x)
# Out:
# PySBD
# แนวคิดเรื่องเครื่องจักรที่คิดได้และสิ่งมีชีวิตเทียมนั้นมีมาตั้งแต่สมัยกรีกโบราณ เช่นหุ่นยนต์ทาลอสแห่งครีต อันเป็นหุ่นยนต์ทองแดงของเทพฮิฟีสตัส แหล่งอารยธรรมใหญ่ ๆ ของโลกมักจะเชื่อเรื่องหุ่นยนต์ที่มีความคล้ายกับมนุษย์ เช่น ในอียิปต์และกรีซ ต่อมา ช่วงกลางศตวรรษที่ 19 และ 20 สิ่งมีชีวิตเทียมเริ่มปรากฏอย่างแพร่หลายในนิยายวิทยาศาสตร์ เช่น แฟรงเกนสไตน์ของแมรี เชลลีย์ หรือ R.U.R.ของกาเรล ชาเปก แนวคิดเหล่านี้ผ่านการอภิปรายมาอย่างแพร่หลาย โดยเฉพาะในแง่ของความหวัง ความกลัว หรือความกังวลด้านศีลธรรมเนื่องจากการมีอยู่ของปัญญาประดิษฐ์
#
#
# กลไกหรือการให้เหตุผลอย่างมีแบบแผน ได้รับการพัฒนาขึ้นโดยนักปรัชญาและนักวิทยาศาสตร์มาตั้งแต่สมัยโบราณ การศึกษาด้านตรรกศาสตร์นำไปสู่การคิดค้นเครื่องคำนวณอิเล็กทรอนิกส์ดิจิทัลที่โปรแกรมได้โดยอาศัยหลักการทางคณิตศาสตร์ของแอลัน ทัวริงและคนอื่น ๆ ทฤษฎีการคำนวณของทัวริงชี้ว่า เครื่องจักรที่รู้จักการสลับตัวเลขระหว่าง 0 กับ 1 สามารถเข้าใจนิรนัยทางคณิตศาสตร์ได้ หลังจากนั้น การค้นพบทางด้านประสาทวิทยา ทฤษฎีสารสนเทศ และไซเบอร์เนติกส์ รวมทั้งทฤษฎีการคำนวณของทัวริง ได้ทำให้นักวิทยาศาสตร์บางกลุ่มเริ่มสนใจพิจารณาความเป็นไปได้ของการสร้าง สมองอิเล็กทรอนิกส์ ขึ้นมาอย่างจริงจัง
#
#
# สาขาปัญญาประดิษฐ์นั้นเริ่มก่อตั้งขึ้นในที่ประชุมวิชาการที่วิทยาลัยดาร์ตมัธ สหรัฐอเมริกาในช่วงหน้าร้อน ค.ศ. 1956[2] โดยผู้ร่วมในการประชุมครั้งนั้น ได้แก่ จอห์น แม็กคาร์ธีย์ มาร์วิน มินสกี อัลเลน นิวเวลล์ อาเธอร์ ซามูเอล และเฮอร์เบิร์ต ไซมอน ที่ได้กลายมาเป็นผู้นำทางสาขาปัญญาประดิษฐ์ในอีกหลายสิบปีต่อมา นักวิทยาศาสตร์และนักศึกษาของพวกเขาเหล่านี้เขียนโปรแกรมที่หลายคนทึ่ง ไม่ว่าจะเป็น คอมพิวเตอร์ที่สามารถเอาชนะคนเล่นหมากรุก แก้ไขปัญหาเกี่ยวกับคำด้วยพีชคณิต พิสูจน์ทฤษฎีทางตรรกวิทยา หรือแม้กระทั่งพูดภาษาอังกฤษได้ ผู้ก่อตั้งสาขาปัญญาประดิษฐ์กลุ่มนี้เชื่อมั่นในอนาคตของเทคโนโลยีใหม่นี้มาก โดยเฮอร์เบิร์ต ไซมอนคาดว่าจะมีเครื่องจักรที่สามารถทำงานทุกอย่างได้เหมือนมนุษย์ภายใน 20 ปีข้างหน้า และมาร์วิน มินสกีก็เห็นพ้องโดยการเขียนว่า "เพียงชั่วอายุคน ปัญหาของการสร้างความฉลาดเทียมจะถูกแก้ไขอย่างยั่งยืน
#
# TIME: 0.010655641555786133

# %% [markdown]
# Both suck for Thai, since Thai has no punctuation marks
#
# The first line where spaCy splits the RUR should not be split acc to Google Translate:
#
# The concept of imaginative machines and artificial beings dates back to ancient Greece. like the robot Talos of Crete. which is a copper robot of the god Hiphaestus The world's major civilizations believed in human-like robots, such as in Egypt and Greece. Later, in the mid-19th and 20th centuries, artificial creatures began to appear in science fiction, such as Frankenstein. Mary Shelley's RUR or Garel Chapec's RUR, these ideas have been widely discussed by

# %% [markdown]
# ##### Norwegian

# %%
# Norwegian
# Take Danish for PySBD (https://en.wikipedia.org/wiki/Bokm%C3%A5l#Differences_from_Danish)

no_text = """
Kunstig intelligens (KI) er en teknikk man bruker for å gi datamaskiner og dataprogrammer en mest mulig intelligent respons.[1] Fagfeltet kunstig intelligens er tverrfaglig av natur, og har vokst fram med bidrag fra blant annet informatikk, matematikk, statistikk, psykologi, nevrologi og lingvistikk. Grenen kunstig intelligens innen informatikk blir definert som studiet og utviklingen av intelligente agenter,[2] der en intelligent agent er et system som observerer sitt miljø og tar avgjørelser for å maksimere sin egen suksess.[3] Andreas Kaplan og Michael Haenlein definerer kunstig intelligens som "et systems evne til å korrekt tolke eksterne data, å lære av slike data, og å bruke denne kunnskapen til å oppnå spesifikke mål og oppgaver gjennom fleksibel tilpasning".[4]
"""

x = time.time()
# PYSBD
seg = pysbd.Segmenter(language="da", clean=False)

print("PySBD")
for i in seg.segment(no_text):
  print(i)

y = time.time()
print("TIME:", y - x)

# SPACY - Erros out for Korean as not supported, so it doesnt seem like just because its listed 
config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }
tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )
tokenizer.add_spacy_tokenizer("nb")
sentence_splitter = SentenceSplitter(
            text_df=pd.DataFrame([no_text], columns=["text"]),
            text_column="text",
            tokenizer=tokenizer,
            language="nb",
            language_column=None)


print("-"*50)
out = sentence_splitter.split_sentences_df()[0].list_sentences.values.tolist()[0]

print("\nspaCy")
for i in out:
  print(i)

print("TIME:", time.time() - y)
# Out:
# PySBD
# Kunstig intelligens (KI) er en teknikk man bruker for å gi datamaskiner og dataprogrammer en mest mulig intelligent respons.[1]
# Fagfeltet kunstig intelligens er tverrfaglig av natur, og har vokst fram med bidrag fra blant annet informatikk, matematikk, statistikk, psykologi, nevrologi og lingvistikk.
# Grenen kunstig intelligens innen informatikk blir definert som studiet og utviklingen av intelligente agenter,[2] der en intelligent agent er et system som observerer sitt miljø og tar avgjørelser for å maksimere sin egen suksess.[3]
# Andreas Kaplan og Michael Haenlein definerer kunstig intelligens som "et systems evne til å korrekt tolke eksterne data, å lære av slike data, og å bruke denne kunnskapen til å oppnå spesifikke mål og oppgaver gjennom fleksibel tilpasning".
# [4]
#
# TIME: 0.01904129981994629
# --------------------------------------------------
# 100%|██████████| 1/1 [00:00<00:00, 106.46it/s]
# spaCy
# Kunstig intelligens (KI) er en teknikk man bruker for å gi datamaskiner og dataprogrammer en mest mulig intelligent respons.[1] Fagfeltet kunstig intelligens er tverrfaglig av natur, og har vokst fram med bidrag fra blant annet informatikk, matematikk, statistikk, psykologi, nevrologi og lingvistikk.
# Grenen kunstig intelligens innen informatikk blir definert som studiet og utviklingen av intelligente agenter,[2] der en intelligent agent er et system som observerer sitt miljø og tar avgjørelser for å maksimere sin egen suksess.[3] Andreas Kaplan og Michael Haenlein definerer kunstig intelligens som "et systems evne til å korrekt tolke eksterne data, å lære av slike data, og å bruke denne kunnskapen til å oppnå spesifikke mål og oppgaver gjennom fleksibel tilpasning".[4]
# TIME: 0.1333620548248291

# %%
wo_brackets = no_text.replace("[1]", "").replace("[2]", "").replace("[3]", "").replace("[4]", "")

config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }
tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )
tokenizer.add_spacy_tokenizer("nb")

sentence_splitter = SentenceSplitter(
            text_df=pd.DataFrame([wo_brackets], columns=["text"]),
            text_column="text",
            tokenizer=tokenizer,
            language="nb",
            language_column=None)


print("-"*50)
out = sentence_splitter.split_sentences_df()[0].list_sentences.values.tolist()[0]

print("\nspaCy")
for i in out:
  print(i)
# Out:
# --------------------------------------------------
# 100%|██████████| 1/1 [00:00<00:00, 114.72it/s]
# spaCy
# Kunstig intelligens (KI) er en teknikk man bruker for å gi datamaskiner og dataprogrammer en mest mulig intelligent respons.
# Fagfeltet kunstig intelligens er tverrfaglig av natur, og har vokst fram med bidrag fra blant annet informatikk, matematikk, statistikk, psykologi, nevrologi og lingvistikk.
# Grenen kunstig intelligens innen informatikk blir definert som studiet og utviklingen av intelligente agenter, der en intelligent agent er et system som observerer sitt miljø og tar avgjørelser for å maksimere sin egen suksess.
# Andreas Kaplan og Michael Haenlein definerer kunstig intelligens som "et systems evne til å korrekt tolke eksterne data, å lære av slike data, og å bruke denne kunnskapen til å oppnå spesifikke mål og oppgaver gjennom fleksibel tilpasning".

# %% [markdown]
# When removing the source brackets spaCy matches pySBD.

# %% [markdown]
# ##### Armenian

# %%
# Armenian
# Choose Greek for pySBD

import time 
# https://hy.wikipedia.org/wiki/%D4%B1%D5%B6%D5%A1%D5%B6%D5%BB%D5%A1%D5%BF_%D5%A3%D6%80%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6
hy_text = """
Չնայած որ անանջատ գրությունը հիմանականում հանդիպում է դասական հունարեն և լատիներեն ձեռագրերում, գրության այս ձևը ավելի հին պատմություն ունի։ Հնագույն դասական հունարենում կամ Ալեքսանդրիայում, գիրը ներկայացնում էին որպես մեծատառերի անանջատ շարք, որոնք շարվում էին աջից ձախ։ Հետագայում սա փոխակերպվեց՝ «բուստրոֆեդոնի», որը ներառում էր տարբեր ուղղությամբ շարված տողեր։ Դրանից ավելի ուշ հռոմեացիները լատիներենը գրելու համար սկսեցին կիրառել էտրուսկական այբուբենը, որում բառերը բաժանելու համար սկզբում օգտագործում էին կետեր, բայց հունական ազդեցությամբ՝ անցում կատարեցին անանջատ գրի[4]։
Մինչև գրքի հայտնաբերումը, լատինական և հունական ձեռագրերը գրվում էին գալարների վրա՝ ստրկացված գրիչների կողմից։ Գրիչը պետք է ուղղակի գրի առներ այն ամենն, ինչ լսում էր։ Քանի որ խոսքը շարունակական էր, գրում բացատներ թողնելը անտրամաբանական էր։ Բացի այդ, այն ժամանակ պապիրուսը և թանաքը շատ թանկ էին և բացատներ չդնելը միջոցները խնայելու եղանակ էր։

Անջատ բառերի բացակայությունը ընթերցողին տալիս էր գրվածը մեկնաբանելու ավելի մեծ ազատություն, քանի որ նա ազատ էր դադարներ տալ և տոնայնությունը փոխել ինչպես ցանկանում է՝ ընթերցանության գործընթացը դարձնելով ավելի սուբյեկտիվ։ Բացատների բացակայությունը որոշ առումով բերում էր նաև երկիմաստության, քանի որ բառերի տարբեր բաժանումը կարող էր գրվածին տալ տարբեր նշանակություն[5]։
"""

x = time.time()
# PYSBD
seg = pysbd.Segmenter(language="el", clean=False)

print("PySBD")
for i in seg.segment(hy_text):
  print(i)

y = time.time()
print("TIME:", y - x)

config = {
            "sentencizer": {"punct_chars": Sentencizer.default_punct_chars + ["\n"]}
        }
tokenizer = MultilingualTokenizer(
            add_pipe_components=["sentencizer"],
            enable_pipe_components="sentencizer",
            config=config,
        )
tokenizer.add_spacy_tokenizer("hy")

sentence_splitter = SentenceSplitter(
            text_df=pd.DataFrame([hy_text], columns=["text"]),
            text_column="text",
            tokenizer=tokenizer,
            language="hy",
            language_column=None)


print("-"*50)
out = sentence_splitter.split_sentences_df()[0].list_sentences.values.tolist()[0]

print("\nspaCy")
for i in out:
  print(i)

print("TIME:", time.time() - y)
# Out:
# PySBD
# Չնայած որ անանջատ գրությունը հիմանականում հանդիպում է դասական հունարեն և լատիներեն ձեռագրերում, գրության այս ձևը ավելի հին պատմություն ունի։ Հնագույն դասական հունարենում կամ Ալեքսանդրիայում, գիրը ներկայացնում էին որպես մեծատառերի անանջատ շարք, որոնք շարվում էին աջից ձախ։ Հետագայում սա փոխակերպվեց՝ «բուստրոֆեդոնի», որը ներառում էր տարբեր ուղղությամբ շարված տողեր։ Դրանից ավելի ուշ հռոմեացիները լատիներենը գրելու համար սկսեցին կիրառել էտրուսկական այբուբենը, որում բառերը բաժանելու համար սկզբում օգտագործում էին կետեր, բայց հունական ազդեցությամբ՝ անցում կատարեցին անանջատ գրի[4]։
#
# Մինչև գրքի հայտնաբերումը, լատինական և հունական ձեռագրերը գրվում էին գալարների վրա՝ ստրկացված գրիչների կողմից։ Գրիչը պետք է ուղղակի գրի առներ այն ամենն, ինչ լսում էր։ Քանի որ խոսքը շարունակական էր, գրում բացատներ թողնելը անտրամաբանական էր։ Բացի այդ, այն ժամանակ պապիրուսը և թանաքը շատ թանկ էին և բացատներ չդնելը միջոցները խնայելու եղանակ էր։
#
#
# Անջատ բառերի բացակայությունը ընթերցողին տալիս էր գրվածը մեկնաբանելու ավելի մեծ ազատություն, քանի որ նա ազատ էր դադարներ տալ և տոնայնությունը փոխել ինչպես ցանկանում է՝ ընթերցանության գործընթացը դարձնելով ավելի սուբյեկտիվ։ Բացատների բացակայությունը որոշ առումով բերում էր նաև երկիմաստության, քանի որ բառերի տարբեր բաժանումը կարող էր գրվածին տալ տարբեր նշանակություն[5]։
#
# TIME: 0.007391452789306641
# --------------------------------------------------
# 100%|██████████| 1/1 [00:00<00:00, 101.33it/s]
# spaCy
# Չնայած որ անանջատ գրությունը հիմանականում հանդիպում է դասական հունարեն և լատիներեն ձեռագրերում, գրության այս ձևը ավելի հին պատմություն ունի։ Հնագույն դասական հունարենում կամ Ալեքսանդրիայում, գիրը ներկայացնում էին որպես մեծատառերի անանջատ շարք, որոնք շարվում էին աջից ձախ։ Հետագայում սա փոխակերպվեց՝ «բուստրոֆեդոնի», որը ներառում էր տարբեր ուղղությամբ շարված տողեր։ Դրանից ավելի ուշ հռոմեացիները լատիներենը գրելու համար սկսեցին կիրառել էտրուսկական այբուբենը, որում բառերը բաժանելու համար սկզբում օգտագործում էին կետեր, բայց հունական ազդեցությամբ՝ անցում կատարեցին անանջատ գրի[4]։
#
# Մինչև գրքի հայտնաբերումը, լատինական և հունական ձեռագրերը գրվում էին գալարների վրա՝ ստրկացված գրիչների կողմից։ Գրիչը պետք է ուղղակի գրի առներ այն ամենն, ինչ լսում էր։ Քանի որ խոսքը շարունակական էր, գրում բացատներ թողնելը անտրամաբանական էր։ Բացի այդ, այն ժամանակ պապիրուսը և թանաքը շատ թանկ էին և բացատներ չդնելը միջոցները խնայելու եղանակ էր։
#
# Անջատ բառերի բացակայությունը ընթերցողին տալիս էր գրվածը մեկնաբանելու ավելի մեծ ազատություն, քանի որ նա ազատ էր դադարներ տալ և տոնայնությունը փոխել ինչպես ցանկանում է՝ ընթերցանության գործընթացը դարձնելով ավելի սուբյեկտիվ։ Բացատների բացակայությունը որոշ առումով բերում էր նաև երկիմաստության, քանի որ բառերի տարբեր բաժանումը կարող էր գրվածին տալ տարբեր նշանակություն[5]։
# TIME: 0.10326886177062988

# %% [markdown]
# Neither of them catches the ":" in the middles that is used as punctuation in Armenian - I guess just because spaCy lists a language doesn't mean it really provides reliable support for all functionalities.

# %% [markdown]
# Given these small tests I assume pySBD to be at least as good as spaCy on ALL languages covered by spaCy even though they may not be officially covered by pySBD. (Note that for languages covered by pySBD, pySBD reports that they outperform spaCy on their repo by a wide margin)
#
# In addition
# - pysbd is 10x faster
# - pysbd has less dependencies
# - pysbd requires less code

# %% [markdown]
# #### PySBD Splitting vs Non-Splitting

# %%
# !git clone -b pysbd-benchmark https://github.com/Muennighoff/hf-translation-benchmark.git
# %cd hf-translation-benchmark
# !pip install -r requirements.txt
# Out:
# Cloning into 'hf-translation-benchmark'...
# remote: Enumerating objects: 281, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 281 (delta 138), reused 219 (delta 86), pack-reused 0
# Receiving objects: 100% (281/281), 267.86 KiB | 7.65 MiB/s, done.
# Resolving deltas: 100% (138/138), done.
# /content/hf-translation-benchmark
# Collecting sacrebleu==1.5.0
#   Downloading sacrebleu-1.5.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.7 MB/s
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.9.0+cu102)
# Collecting transformers[sentencepiece]>=4.1
#   Downloading transformers-4.11.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 15.5 MB/s
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (0.42.1)
# Collecting mecab-python3==1.0.4
#   Downloading mecab_python3-1.0.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (488 kB)
#      |████████████████████████████████| 488 kB 62.1 MB/s
# Collecting mecab-ko-dic==1.0.0
#   Downloading mecab-ko-dic-1.0.0.tar.gz (33.2 MB)
#      |████████████████████████████████| 33.2 MB 58 kB/s
# Collecting nagisa==0.2.7
#   Downloading nagisa-0.2.7-cp37-cp37m-manylinux1_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.2 MB/s
# Collecting pysbd==0.3.4
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 10.5 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nagisa==0.2.7->-r requirements.txt (line 7)) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nagisa==0.2.7->-r requirements.txt (line 7)) (1.15.0)
# Collecting DyNet
#   Downloading dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 61.1 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (2.23.0)
# Collecting huggingface-hub>=0.0.17
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.7 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 60.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (4.8.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 66.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (4.62.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (3.0.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (2019.12.20)
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 62.2 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (3.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from DyNet->nagisa==0.2.7->-r requirements.txt (line 7)) (0.29.24)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]>=4.1->-r requirements.txt (line 3)) (7.1.2)
# Building wheels for collected packages: mecab-ko-dic
#   Building wheel for mecab-ko-dic (setup.py) ... done
#   Created wheel for mecab-ko-dic: filename=mecab_ko_dic-1.0.0-py3-none-any.whl size=33424414 sha256=652af1d7e728a2a14f02d1ad1967d48aa9033ffeebff26c244960935f8fb6eeb
#   Stored in directory: /root/.cache/pip/wheels/48/11/b3/67b14aad404ab5f33e707e5d95c386f6e894d977aa3dcba107
# Successfully built mecab-ko-dic
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers, sentencepiece, portalocker, DyNet, sacrebleu, pysbd, nagisa, mecab-python3, mecab-ko-dic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed DyNet-2.1.2 huggingface-hub-0.0.17 mecab-ko-dic-1.0.0 mecab-python3-1.0.4 nagisa-0.2.7 portalocker-2.3.2 pysbd-0.3.4 pyyaml-5.4.1 sacrebleu-1.5.0 sacremoses-0.0.46 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.11.1

# %%
# !nvidia-smi
# Out:
# Thu Sep 30 09:32:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from data.data import TRANSLATION_BENCHMARKS
from models.m2m import SRC_TO_PYSBD, SRC_TO_PYSBD_INDIRECT

# %%
### GET NON-FAMILY LANGUAGES ###

test_lang_pairs = set()
for lang_pair in TRANSLATION_BENCHMARKS:
    src, tar = lang_pair.split("-")[0], lang_pair.split("-")[-1]
    # Only makes sense, when the language is the source lang, as thats when we split
    if (src in SRC_TO_PYSBD_INDIRECT.keys()):
        test_lang_pairs.add(lang_pair)
test_lang_pairs
# Out:
# {'et-en',
#  'fi-en',
#  'gu-en',
#  'hu-en',
#  'km-en',
#  'ko-en',
#  'lt-en',
#  'lv-en',
#  'ps-en',
#  'ro-en',
#  'ta-en',
#  'tr-en'}

# %%
# BLEU Score is expected to be higher as calculated over more words now
# https://en.wikipedia.org/wiki/BLEU
reports = ""
for pair in test_lang_pairs:
    # !python main.py --model m2m --weights facebook/m2m100_418M --data {pair} --sample 500 --baseline --nosplitting
    reports += open("out.txt", "r").read()
    reports += "\n"*2

    # !python main.py --model m2m --weights facebook/m2m100_418M --data {pair} --sample 500 --mergesents 10 --nosplitting
    reports += open("out.txt", "r").read()
    reports += "\n"*2

    # !python main.py --model m2m --weights facebook/m2m100_418M --data {pair} --sample 500 --mergesents 10
    reports += open("out.txt", "r").read()


    reports += "\n"*20

with open("fin_report_sent10.txt", "w") as f:
    f.write(reports)
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Downloading http://data.statmt.org/wmt18/translation-task/test.tgz to /root/.sacrebleu/wmt18/test.tgz
# Checksum passed: f996c245ecffea23d0006fa4c34e9064
# Extracting /root/.sacrebleu/wmt18/test.tgz
# Processing /root/.sacrebleu/wmt18/raw/test/newstest2018-eten-src.et.sgm to /root/.sacrebleu/wmt18/et-en.et
# Processing /root/.sacrebleu/wmt18/raw/test/newstest2018-eten-ref.en.sgm to /root/.sacrebleu/wmt18/et-en.en
# Starting translation from et to en.
# Baseline: Preds reduced to 100 samples with 5 sentences each.
# Baseline: Target reduced to 100 samples with 5 sentences each.
# Scored 27.808906292791907 on language pair et-en.
# 100% 1/1 [05:12<00:00, 312.90s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# et-en
#
# BLEU
# 27.808906292791907
#
# AVG SPEED
# 0.52569118309021
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        45.76%        2.056s        45.76%        2.056s      31.985us       0.000us         0.00%       0.000us       0.000us         64271
#                                      aten::index_select         1.56%      70.163ms        38.14%        1.713s     285.314us     104.503ms         6.43%     104.503ms      17.403us          6005
#                                         aten::embedding         0.03%       1.124ms        34.77%        1.562s      12.910ms       0.000us         0.00%       1.240ms      10.248us           121
#                                            aten::linear         1.61%      72.447ms        18.81%     845.206ms      72.018us       0.000us         0.00%     787.989ms      67.143us         11736
#                                         cudaMemcpyAsync        15.27%     685.917ms        15.27%     685.917ms     216.856us       0.000us         0.00%       0.000us       0.000us          3163
#                                              aten::item         0.06%       2.817ms        15.12%     679.414ms     614.298us       0.000us         0.00%       1.096ms       0.991us          1106
#                               aten::_local_scalar_dense         0.15%       6.817ms        15.06%     676.664ms     611.812us       1.109ms         0.07%       1.109ms       1.003us          1106
#                                        aten::is_nonzero         0.02%     866.000us        14.72%     661.274ms       1.827ms       0.000us         0.00%     365.000us       1.008us           362
#                                            aten::matmul         1.93%      86.711ms        10.37%     465.787ms      39.689us       0.000us         0.00%     741.577ms      63.188us         11736
#                                                aten::mm         3.50%     157.134ms         7.00%     314.640ms      26.810us     741.577ms        45.64%     741.577ms      63.188us         11736
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 4.493s
# Self CUDA time total: 1.625s
#
#
# EXAMPLE
# Src: Eestis ja Hispaanias peeti kinni neli Kemerovo grupeeringu liiget Postimehe andmetel pidas politsei Hispaanias kinni Eesti allilmas tegutseva niinimetatud Kemerovo grupeeringu juhi Slava Gulevitši, keda kuritegelikus maailmas tuntakse Slava Kemerovski nime all. Hispaanias kinni peetud Gulevitš vahistati kohtu loal. Eile võttis kohus ka kolm Eestis kinni peetud kahtlustatavat vahi alla. Kahtlustuse järgi on tegemist niinimetatud Kemerovo kuritegeliku ühenduse liikmetega vanuses 27-57 eluaastat, kes panevad peamiselt toime narkokuritegusid.
# Pred: Four members of the Kemerovo group arrested in Estonia and Spain According to the postman, the police in Spain have arrested the so-called Kemerovo group leader Slava Gulevich, who in the criminal world is known under the name of Slava Kemerovsky. Gulevich, detained in Spain, was arrested with court permission. The court also arrested three suspects detained in Estonia. It is suspected that they are members of the so-called Kemerovo criminal community between the ages of 27 and 57 who are mainly committing drug crimes.
# Ref: Four members of the Kemerovo group arrested in Estonia and Spain According to Postimees, police in Spain have arrested Slava Gulevich, the head of the so-called Kemerovo group operating in the Estonian underworld, known in the criminal world by the name of Slava Kemerovsky. A court had issued for the arrest of Gulevich in Spain. Yesterday the court also ordered that three suspects detained in Estonia be held. According to the complaint, they are members of the so-called Kemerovo criminal organization ranging in age from 27 to 57 and committing primarily drug-related crimes.
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from et to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Sentence is too long (347 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (351 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (469 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (488 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (470 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (500 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (717 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (448 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (329 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (422 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (330 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (466 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (307 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (310 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (385 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (306 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (366 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (423 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (328 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (491 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (354 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (396 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (302 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (308 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (519 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (343 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (396 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (344 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (340 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (479 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (425 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (347 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (482 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (392 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (347 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 18.099518249474706 on language pair et-en.
# 100% 1/1 [04:15<00:00, 255.12s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# et-en
#
# BLEU
# 18.099518249474706
#
# AVG SPEED
# 3.8886845874786378
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        31.95%        2.335s        31.95%        2.335s      21.713us       0.000us         0.00%       0.000us       0.000us        107546
#                                         cudaMemcpyAsync        27.64%        2.020s        27.64%        2.020s     308.827us       0.000us         0.00%       0.000us       0.000us          6542
#                                              aten::item         0.08%       6.040ms        27.41%        2.003s     845.941us       0.000us         0.00%       2.334ms       0.986us          2368
#                               aten::_local_scalar_dense         0.19%      13.566ms        27.32%        1.997s     843.461us       2.370ms         0.06%       2.370ms       1.001us          2368
#                                        aten::is_nonzero         0.03%       1.933ms        26.92%        1.968s       2.321ms       0.000us         0.00%     849.000us       1.001us           848
#                                      aten::index_select         2.12%     154.600ms        24.76%        1.810s     181.804us     454.841ms        11.59%     454.841ms      45.690us          9955
#                                         aten::embedding         0.03%       1.884ms        20.84%        1.524s       7.618ms       0.000us         0.00%       3.126ms      15.630us           200
#                                            aten::linear         1.62%     118.244ms        20.82%        1.522s      78.455us       0.000us         0.00%        1.328s      68.446us         19399
#                                            aten::matmul         1.88%     137.648ms        12.31%     899.656ms      46.376us       0.000us         0.00%        1.250s      64.431us         19399
#                                                aten::mm         3.31%     241.913ms         6.94%     507.376ms      26.155us        1.250s        31.84%        1.250s      64.431us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.310s
# Self CUDA time total: 3.926s
#
#
# EXAMPLE
# Src: Eestis ja Hispaanias peeti kinni neli Kemerovo grupeeringu liiget Postimehe andmetel pidas politsei Hispaanias kinni Eesti allilmas tegutseva niinimetatud Kemerovo grupeeringu juhi Slava Gulevitši, keda kuritegelikus maailmas tuntakse Slava Kemerovski nime all. Hispaanias kinni peetud Gulevitš vahistati kohtu loal. Eile võttis kohus ka kolm Eestis kinni peetud kahtlustatavat vahi alla. Kahtlustuse järgi on tegemist niinimetatud Kemerovo kuritegeliku ühenduse liikmetega vanuses 27-57 eluaastat, kes panevad peamiselt toime narkokuritegusid. Hispaanias Malaga provintsis Mijases peeti kinni kuritegeliku ühenduse väidetav juht. Eestis peeti kahtlustatavana kinni kolm meest, neist üks on kogutud andmete kohaselt kuritegeliku ühenduse juhtfiguur ning kaks on kuritegeliku ühenduse liikmed. Kogutud andmed viitavad sellele, et kuritegelikus ühenduses olid selgelt ära jaotatud ülesanded ja rollid. Kuritegeliku ühenduse tegevuse eesmärk oli toime panna narkokuritegusid ning seeläbi teenida kriminaaltulu", kommenteeris kriminaalasja kohtueelse menetluse juht, riigiprokurör Vahur Verte. "Me ei välista, et kõnealuses kriminaalasjas kahtlustatavate ring suureneb", lisas prokurör.
# Pred: In Estonia and Spain, four members of the Kemerovo group were arrested by the police in Spain, according to Postman, arrested the so-called Kemerovo group leader Slava Gulevich, who in the criminal world is known as Slava Kemerovich. in Spain, the Gulevich was arrested by court permission. yesterday, the court also took three suspects arrested in Estonia. according to the suspicion, it is the so-called Kemerovo criminal community members aged 27-57 years, who are mainly committing narcotic crimes. in Spain, the province of Malaya, in the province of Mijas, the criminal world is known as Slava Kemerovich. in Spain, the Gulevich was arrested by court permission. yesterday, the court also took three suspects arrested in Estonia. according to the suspicion, it is The head of the preliminary proceedings, Prosecutor Vahur Verte. “We do not exclude that the number of suspects in the criminal case will increase,” the prosecutor added.
# Ref: Four members of the Kemerovo group arrested in Estonia and Spain According to Postimees, police in Spain have arrested Slava Gulevich, the head of the so-called Kemerovo group operating in the Estonian underworld, known in the criminal world by the name of Slava Kemerovsky. A court had issued for the arrest of Gulevich in Spain. Yesterday the court also ordered that three suspects detained in Estonia be held. According to the complaint, they are members of the so-called Kemerovo criminal organization ranging in age from 27 to 57 and committing primarily drug-related crimes. In the Mijas province of Malaga in Spain, the alleged boss of a criminal organization was detained. Three men were detained as suspects in Estonia; according to the gathered evidence, one of them is a leading figure of a criminal organization and two of them are members of a criminal organization. The gathered information points to a clear division of roles and functions in the criminal organization. The objective of the criminal organizations activity was to commit to drug crimes, and thereby earn criminal gains,” commented the head of pretrial proceedings in the criminal case, public prosecutor Vahur Verte. “We can’t rule out that the number of suspects in this criminal case will increase.”
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from et to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped et to de
# Mapped et to de
# Scored 27.630917914776905 on language pair et-en.
# 100% 1/1 [02:04<00:00, 124.26s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# et-en
#
# BLEU
# 27.630917914776905
#
# AVG SPEED
# 1.9657607030868531
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        46.06%        1.793s        46.06%        1.793s      47.339us       0.000us         0.00%       0.000us       0.000us         37869
#                                      aten::index_select         0.94%      36.680ms        40.80%        1.588s     495.453us     289.411ms        16.70%     289.411ms      90.300us          3205
#                                         aten::embedding         0.02%     622.000us        38.81%        1.511s      23.241ms       0.000us         0.00%     418.000us       6.431us            65
#                                         cudaMemcpyAsync        25.93%        1.009s        25.93%        1.009s     125.259us       0.000us         0.00%       0.000us       0.000us          8057
#                                              aten::item         0.18%       7.075ms        25.60%     996.281ms     334.772us       0.000us         0.00%       2.924ms       0.983us          2976
#                               aten::_local_scalar_dense         0.43%      16.573ms        25.42%     989.418ms     332.466us       2.976ms         0.17%       2.976ms       1.000us          2976
#                                        aten::is_nonzero         0.05%       1.895ms        24.37%     948.544ms     981.930us       0.000us         0.00%     966.000us       1.000us           966
#                                            aten::linear         0.98%      38.059ms        11.28%     439.126ms      69.658us       0.000us         0.00%     608.206ms      96.479us          6304
#                                            aten::matmul         1.16%      45.171ms         6.17%     240.073ms      38.083us       0.000us         0.00%     577.769ms      91.651us          6304
#                                                aten::mm         2.06%      80.111ms         4.14%     161.185ms      25.569us     577.769ms        33.35%     577.769ms      91.651us          6304
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 3.892s
# Self CUDA time total: 1.733s
#
#
# EXAMPLE
# Src: Eestis ja Hispaanias peeti kinni neli Kemerovo grupeeringu liiget Postimehe andmetel pidas politsei Hispaanias kinni Eesti allilmas tegutseva niinimetatud Kemerovo grupeeringu juhi Slava Gulevitši, keda kuritegelikus maailmas tuntakse Slava Kemerovski nime all. Hispaanias kinni peetud Gulevitš vahistati kohtu loal. Eile võttis kohus ka kolm Eestis kinni peetud kahtlustatavat vahi alla. Kahtlustuse järgi on tegemist niinimetatud Kemerovo kuritegeliku ühenduse liikmetega vanuses 27-57 eluaastat, kes panevad peamiselt toime narkokuritegusid. Hispaanias Malaga provintsis Mijases peeti kinni kuritegeliku ühenduse väidetav juht. Eestis peeti kahtlustatavana kinni kolm meest, neist üks on kogutud andmete kohaselt kuritegeliku ühenduse juhtfiguur ning kaks on kuritegeliku ühenduse liikmed. Kogutud andmed viitavad sellele, et kuritegelikus ühenduses olid selgelt ära jaotatud ülesanded ja rollid. Kuritegeliku ühenduse tegevuse eesmärk oli toime panna narkokuritegusid ning seeläbi teenida kriminaaltulu", kommenteeris kriminaalasja kohtueelse menetluse juht, riigiprokurör Vahur Verte. "Me ei välista, et kõnealuses kriminaalasjas kahtlustatavate ring suureneb", lisas prokurör.
# Pred: In Estonia and Spain, four members of the Kemerovo group have been arrested, according to Postman, the police in Spain have arrested the so-called Kemerovo group leader Slava Gulevich, who in the criminal world is known under the name of Slava Kemerovsky. Gulevich, detained in Spain, was arrested with court permission. The court also arrested three suspects detained in Estonia. It is suspected that they are members of the so-called Kemerovo criminal community between the ages of 27 and 57 who are mainly committing drug crimes. In Mijases, Spain, the alleged leader of a criminal community has been arrested. In Estonia, three men were arrested as suspects, one of whom, according to data collected, is the leader of the criminal community and two are members of the criminal community. The data collected indicates that the criminal community clearly distributed tasks and roles. The purpose of the criminal community’s activities was to deal with drug crimes and thus earn criminal income,” said Vahur Verte, the head of the pre-judical proceedings in the criminal case. “We do not exclude that the number of suspects in the criminal case will increase,” the prosecutor added.
# Ref: Four members of the Kemerovo group arrested in Estonia and Spain According to Postimees, police in Spain have arrested Slava Gulevich, the head of the so-called Kemerovo group operating in the Estonian underworld, known in the criminal world by the name of Slava Kemerovsky. A court had issued for the arrest of Gulevich in Spain. Yesterday the court also ordered that three suspects detained in Estonia be held. According to the complaint, they are members of the so-called Kemerovo criminal organization ranging in age from 27 to 57 and committing primarily drug-related crimes. In the Mijas province of Malaga in Spain, the alleged boss of a criminal organization was detained. Three men were detained as suspects in Estonia; according to the gathered evidence, one of them is a leading figure of a criminal organization and two of them are members of a criminal organization. The gathered information points to a clear division of roles and functions in the criminal organization. The objective of the criminal organizations activity was to commit to drug crimes, and thereby earn criminal gains,” commented the head of pretrial proceedings in the criminal case, public prosecutor Vahur Verte. “We can’t rule out that the number of suspects in this criminal case will increase.”
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Downloading http://data.statmt.org/wmt16/translation-task/test.tgz to /root/.sacrebleu/wmt16/test.tgz
# Checksum passed: 3d809cd0c2c86adb2c67034d15c4e446
# Extracting /root/.sacrebleu/wmt16/test.tgz
# Processing /root/.sacrebleu/wmt16/raw/test/newstest2016-tren-src.tr.sgm to /root/.sacrebleu/wmt16/tr-en.tr
# Processing /root/.sacrebleu/wmt16/raw/test/newstest2016-tren-ref.en.sgm to /root/.sacrebleu/wmt16/tr-en.en
# Starting translation from tr to en.
# Baseline: Preds reduced to 100 samples with 5 sentences each.
# Baseline: Target reduced to 100 samples with 5 sentences each.
# Scored 23.48287188418639 on language pair tr-en.
# 100% 1/1 [05:15<00:00, 315.07s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# tr-en
#
# BLEU
# 23.48287188418639
#
# AVG SPEED
# 0.5267612552642822
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        40.96%        2.129s        40.96%        2.129s      25.360us       0.000us         0.00%       0.000us       0.000us         83953
#                                      aten::index_select         1.74%      90.328ms        32.67%        1.698s     216.207us     186.506ms         8.42%     186.506ms      23.744us          7855
#                                         aten::embedding         0.03%       1.479ms        28.93%        1.504s       9.519ms       0.000us         0.00%       1.659ms      10.500us           158
#                                            aten::linear         1.77%      91.796ms        20.44%        1.063s      69.347us       0.000us         0.00%        1.034s      67.443us         15325
#                                         cudaMemcpyAsync        17.35%     902.182ms        17.35%     902.182ms     218.976us       0.000us         0.00%       0.000us       0.000us          4120
#                                              aten::item         0.07%       3.710ms        17.20%     894.083ms     623.054us       0.000us         0.00%       1.427ms       0.994us          1435
#                               aten::_local_scalar_dense         0.17%       8.682ms        17.13%     890.423ms     620.504us       1.436ms         0.06%       1.436ms       1.001us          1435
#                                        aten::is_nonzero         0.02%       1.137ms        16.75%     870.762ms       1.841ms       0.000us         0.00%     475.000us       1.004us           473
#                                            aten::matmul         2.10%     109.090ms        11.18%     581.363ms      37.936us       0.000us         0.00%     972.426ms      63.454us         15325
#                                                aten::mm         3.69%     191.951ms         7.49%     389.241ms      25.399us     972.426ms        43.90%     972.426ms      63.454us         15325
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.198s
# Self CUDA time total: 2.215s
#
#
# EXAMPLE
# Src: Profesör 911'i Arayarak Kız Arkadaşını Öldürdüğünü İtiraf Etti 911'i arayan Üniversite Profesörü Shannon Lamb, polise kız arkadaşını silahla vurduğunu ve polisin evlerin gelmesi gerektiğini sesi yalnızca biraz titrek şekilde söyledi. Lamb, "sevimli köpeğinin" canlı ve muhtemelen üzgün olduğunu ve ölen kadının ailesinin telefonlarının kadının cep telefonunda bulunabileceğini belirtti. Polisler evde Amy Prentiss'in cansız bedenini ve beyaz bir not defterine el yazısıyla yazılmış bir not buldu: "Çok üzgünüm, keşke her şeyi geri döndürebilsem, Amy'yi çok sevmiştim ve o da bugüne kadar beni seven tek kadındı" okunan notu Lamb'in imzaladığını belirtti memurlar. Mississippi, Cleveland'deki Delta Eyalet Üniversitesi için iki çevrimiçi ders veren Lamb'in, polisin sevilen tarih profesörü Ethan Scmidt'in de Lamb tarafından ofisinin önünde vurulup öldürüldüğünü düşündüğü okul kampüsüne doğru çoktan 300 mil yol aldığına dair bir bulgu yoktu.
# Pred: Professor Calls 911 To Confess That He Killed His Girlfriend University Professor Shannon Lamb, who called 911, told the police that he shot his girlfriend with a gun and the police's voice that the houses should come just a bit vibrantly. Lamb said the "love dog" was alive and probably sad, and the family's phones could be found on the woman's mobile phone. The police found Amy Prentiss's immortal body at home and a handwritten note on a white notebook: "I'm very sorry, I wish I could get everything back, I loved Amy so much and she was the only woman to love me so far." There was no evidence that Lamb, who gave two online lessons to the Delta State University in Mississippi, Cleveland, had already gone 300 miles to the school campus where the police’s beloved history professor Ethan Scmidt believed to have been shot and killed by Lamb in front of his office.
# Ref: In 911 Call, Professor Admits to Shooting Girlfriend In a 911 call, his voice only slightly shaky, college professor Shannon Lamb told police he had shot his girlfriend and officers needed to get over to their house. Lamb made a point to say his "sweet dog" was there alive and probably upset, and said the dead woman's family contacts could be found on her phone. Inside the home, officers found Amy Prentiss' body and a hand-written note scribbled on a white legal pad: "I am so very sorry I wish I could take it back I loved Amy and she is the only woman who ever loved me," read the letter authorities say was signed by Lamb. There was no indication that Lamb, who was teaching two online classes for Delta State University in Cleveland, Mississippi, had already traveled 300 miles to the school's campus, where police believe he shot and killed a well-liked history professor, Ethan Schmidt, in the doorway to his office.
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from tr to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Sentence is too long (444 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (306 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (376 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (350 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (308 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (352 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (309 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (312 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (491 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (450 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (325 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (459 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (590 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (507 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (532 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (329 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (568 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (385 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (306 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (332 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (359 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (398 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (396 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (327 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (320 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (412 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (432 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (402 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (350 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (354 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (366 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (348 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (351 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (384 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (339 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (444 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 13.98969632185776 on language pair tr-en.
# 100% 1/1 [04:14<00:00, 254.68s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# tr-en
#
# BLEU
# 13.98969632185776
#
# AVG SPEED
# 3.894609055519104
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        32.18%        2.330s        32.18%        2.330s      21.763us       0.000us         0.00%       0.000us       0.000us        107049
#                                         cudaMemcpyAsync        26.74%        1.936s        26.74%        1.936s     261.116us       0.000us         0.00%       0.000us       0.000us          7413
#                                              aten::item         0.09%       6.553ms        26.56%        1.922s     730.979us       0.000us         0.00%       2.587ms       0.984us          2630
#                               aten::_local_scalar_dense         0.21%      15.083ms        26.47%        1.916s     728.566us       2.631ms         0.07%       2.631ms       1.000us          2630
#                                        aten::is_nonzero         0.03%       1.952ms        25.98%        1.881s       2.130ms       0.000us         0.00%     883.000us       1.000us           883
#                                      aten::index_select         2.09%     151.525ms        25.03%        1.812s     182.939us     461.088ms        12.05%     461.088ms      46.551us          9905
#                                         aten::embedding         0.03%       1.918ms        21.15%        1.531s       7.694ms       0.000us         0.00%       2.961ms      14.879us           199
#                                            aten::linear         1.59%     115.403ms        18.62%        1.348s      69.826us       0.000us         0.00%        1.322s      68.510us         19302
#                                            aten::matmul         1.89%     137.074ms        10.17%     736.427ms      38.153us       0.000us         0.00%        1.245s      64.491us         19302
#                                                aten::mm         3.28%     237.479ms         6.76%     489.477ms      25.359us        1.245s        32.54%        1.245s      64.491us         19302
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.239s
# Self CUDA time total: 3.826s
#
#
# EXAMPLE
# Src: Profesör 911'i Arayarak Kız Arkadaşını Öldürdüğünü İtiraf Etti 911'i arayan Üniversite Profesörü Shannon Lamb, polise kız arkadaşını silahla vurduğunu ve polisin evlerin gelmesi gerektiğini sesi yalnızca biraz titrek şekilde söyledi. Lamb, "sevimli köpeğinin" canlı ve muhtemelen üzgün olduğunu ve ölen kadının ailesinin telefonlarının kadının cep telefonunda bulunabileceğini belirtti. Polisler evde Amy Prentiss'in cansız bedenini ve beyaz bir not defterine el yazısıyla yazılmış bir not buldu: "Çok üzgünüm, keşke her şeyi geri döndürebilsem, Amy'yi çok sevmiştim ve o da bugüne kadar beni seven tek kadındı" okunan notu Lamb'in imzaladığını belirtti memurlar. Mississippi, Cleveland'deki Delta Eyalet Üniversitesi için iki çevrimiçi ders veren Lamb'in, polisin sevilen tarih profesörü Ethan Scmidt'in de Lamb tarafından ofisinin önünde vurulup öldürüldüğünü düşündüğü okul kampüsüne doğru çoktan 300 mil yol aldığına dair bir bulgu yoktu. Delta Eyalet Üniversitesi polis şefi Lynn Buford üniversite yetkililerinin saat 10:18'de atış duyduğunu söyledi. Lamb'in vahim 911 çağrısını ise bundan kısa bir süre sonra yaptığını da belirtti. Günün sonunda bir ölüm daha gerçekleşti: Lamb, polisin kendisine yaklaştığı sırada intihar etti. Okul atışının öğrencileri ve profesörleri kilitli kapıların ardına saklanmasına sebep olmasından bir gün sonra yetkililer halen Lamb'i neyin bunu yapmaya ittiğini araştırıyorlardı. Eyaletin her iki yanında da soruşturma görevlilerinin yanı sıra onu bilen öğrencilerin ve personelin çıkardığı detaylar yetenekli ama muhtemelen sorunlu bir öğretmen resmi çizdi.
# Pred: Professor Confessed He Killed His Girlfriend by Calling 911 University Professor Shannon Lamb, calling 911, told the police that he shot his girlfriend with a gun and the police's voice that the houses should come just a bit vibrant. Lamb noted that his "love dog" was alive and probably sad and that the family's phones of the deceased woman could be found on the woman's mobile phone. Police found a handwritten note of Amy Prentiss's unhealthy body and a white notebook at home: "I am very sorry, I wish I could return everything, I loved Amy very much and she was the only woman to love me so far." Lamb noted that his "love dog" was alive and possibly sad and that the family's phones of the deceased woman could be found on the woman's mobile phone. He said he heard Lamb's devastating 911 call and said he did it shortly after that, and another death occurred at the end of the day: Lamb committed suicide when the police approached him. One day after the school shooting caused students and professors to hide behind the closed doors, the authorities were still investigating what pushed Lamb to do it.
# Ref: In 911 Call, Professor Admits to Shooting Girlfriend In a 911 call, his voice only slightly shaky, college professor Shannon Lamb told police he had shot his girlfriend and officers needed to get over to their house. Lamb made a point to say his "sweet dog" was there alive and probably upset, and said the dead woman's family contacts could be found on her phone. Inside the home, officers found Amy Prentiss' body and a hand-written note scribbled on a white legal pad: "I am so very sorry I wish I could take it back I loved Amy and she is the only woman who ever loved me," read the letter authorities say was signed by Lamb. There was no indication that Lamb, who was teaching two online classes for Delta State University in Cleveland, Mississippi, had already traveled 300 miles to the school's campus, where police believe he shot and killed a well-liked history professor, Ethan Schmidt, in the doorway to his office. Delta State University police chief Lynn Buford said university officials heard about the shooting at 10:18 a.m. He said Lamb made the fateful 911 call sometime after that. By the end of the day, there would be one more death: Lamb took his own life as police closed in on him. A day after the school shooting forced students and faculty to hide behind locked doors, authorities were still trying to piece together what motivated Lamb. The details released by investigators at both ends of the state as well as students and staff who knew him helped paint a picture of a talented but possibly troubled teacher.
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from tr to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped tr to kk
# Sentence is too long (314 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (363 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped tr to kk
# Scored 23.641639465962392 on language pair tr-en.
# 100% 1/1 [02:21<00:00, 141.04s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# tr-en
#
# BLEU
# 23.641639465962392
#
# AVG SPEED
# 2.231888146400452
#
# ...
#                                         cudaMemcpyAsync        17.71%     914.270ms        17.71%     914.270ms     223.319us       0.000us         0.00%       0.000us       0.000us          4094
#                                              aten::item         0.07%       3.451ms        17.56%     906.448ms     635.658us       0.000us         0.00%       1.435ms       1.006us          1426
#                               aten::_local_scalar_dense         0.16%       8.279ms        17.49%     903.039ms     633.267us       1.443ms         0.07%       1.443ms       1.012us          1426
#                                        aten::is_nonzero         0.02%       1.054ms        17.13%     884.331ms       1.882ms       0.000us         0.00%     487.000us       1.036us           470
#                                            aten::matmul         2.06%     106.380ms        10.99%     567.258ms      37.251us       0.000us         0.00%     962.653ms      63.216us         15228
#                                                aten::mm         3.63%     187.261ms         7.41%     382.390ms      25.111us     962.653ms        43.84%     962.653ms      63.216us         15228
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.163s
# Self CUDA time total: 2.196s
#
#
# EXAMPLE
# Src: சர்வதேச தகவல்களை அறிந்து கொள்ளும் தினம் இன்று ஆகும். இதனை முன்னிட்டு வெகுஜனஊடகத்துறை அமைச்சு தகவல் மாதத்தை பிரகடனப்படுத்தியுள்ளது. இம் மாதம் 15 ஆம் திகதி தொடக்கம் அடுத்த மாதம் 15 ஆம் திகதி வரையில் இடம்பெறும். தகவல் அறிந்து கொள்ளும் உரிமை குறித்து செயற்படுவதில் ஊக்குவிப்பதற்கான பல வேலைத்திட்டங்கள் இக் காலப்பகுதியில் நடைமுறைப்படுத்தப்படும். இலங்கையில் 2016 ஆம் ஆண்டில் தகவல்களை அறிந்து கொள்ளும் சட்டம் பாராளுமன்றத்தில் நிறை வேற்றப்படும். ஜனநாயகத்தை மேலும் வலுப்படுத்தும் நடவடிக்கையாக இது இடம்பெற்றள்ளது. தற்பொழுது இந்த சட்டம் உலகத்தில் நான்காவது சட்டமாக தரப்படுத்தப்பட்டுள்ளது. டெல்லியில் உள்ள பாஜக தலைமையகத்தில் பிளாஸ்டிக் பொருட்களின் பயன்பாடு தடை செய்யப்பட்டுள்ளது. அங்கு வாட்டர் பாட்டில் போன்ற ஒருமுறை பயன்படுத்தக்கூடிய பிளாஸ்டிக் பொருட்கள் தடை செய்யப்பட்டுள்ளது. இந்தியா தற்போது அடுத்த தேர்தல் பரபரப்பிற்கு தயாராகி வருகிறது.
# Pred: The International Information Day is today. This has been scheduled by the previous State Security Information Month. This May 15th begins on the next May 15th will be held on the next May 15th. A number of workshops on the publication in the practice of the right to know information will be carried out in this period. The goal is to get information in 2016 will be completed in the National Security Council. This has been placed on the action of further marketing of democracy. This plan will be legally registered in the world. The main platform on the Internet has been used for the use of platforms such as platforms. The next year will be used for the use of platforms such as platforms.
# Ref: Today is the International day for access to information. On account of this, the Ministry of Public media department has announced Information month. This will be held from the 15th of this month until the 15th of next month. During this period many programs to encourage actions regarding the right to access information will be implemented. The law to access information will be passed in the Sri Lankan parliament in 2016. This activity will further strengthen democracy. This law is currently ranked as the fourth of its kind in the world. Usage of plastic products banned at BJP headquarters in Delhi. The usage of single use plastic products like water bottles is banned there. India is getting ready for the busy elections.
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from ta to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped ta to hi
# Sentence is too long (390 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (375 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (431 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (338 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (336 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (633 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (711 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (327 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (362 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (320 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (393 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (492 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (606 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (745 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (391 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (304 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (311 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (347 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (386 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (356 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (439 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (503 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (363 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (454 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (603 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (443 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (370 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (457 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (376 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (368 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (459 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped ta to hi
# Scored 3.6944761183545007 on language pair ta-en.
# 100% 1/1 [03:48<00:00, 228.87s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# ta-en
#
# BLEU
# 3.6944761183545007
#
# AVG SPEED
# 3.682590136528015
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        41.52%        2.174s        41.52%        2.174s      26.065us       0.000us         0.00%       0.000us       0.000us         83421
#                                      aten::index_select         1.74%      91.264ms        33.45%        1.752s     224.447us     170.419ms         7.77%     170.419ms      21.835us          7805
#                                         aten::embedding         0.03%       1.452ms        29.72%        1.556s       9.913ms       0.000us         0.00%       1.604ms      10.217us           157
#                                            aten::linear         1.75%      91.596ms        20.00%        1.047s      68.779us       0.000us         0.00%        1.024s      67.220us         15228
#                                         cudaMemcpyAsync        17.43%     912.650ms        17.43%     912.650ms     222.924us       0.000us         0.00%       0.000us       0.000us          4094
#                                              aten::item         0.07%       3.533ms        17.27%     904.394ms     634.217us       0.000us         0.00%       1.415ms       0.992us          1426
#                               aten::_local_scalar_dense         0.16%       8.567ms        17.20%     900.956ms     631.806us       1.431ms         0.07%       1.431ms       1.004us          1426
#                                        aten::is_nonzero         0.02%       1.070ms        16.84%     881.788ms       1.876ms       0.000us         0.00%     470.000us       1.000us           470
#                                            aten::matmul         2.04%     107.071ms        11.00%     576.263ms      37.842us       0.000us         0.00%     963.015ms      63.240us         15228
#                                                aten::mm         3.63%     189.872ms         7.41%     388.073ms      25.484us     963.015ms        43.90%     963.015ms      63.240us         15228
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.237s
# Self CUDA time total: 2.194s
#
#
# EXAMPLE
# Src: சர்வதேச தகவல்களை அறிந்து கொள்ளும் தினம் இன்று ஆகும். இதனை முன்னிட்டு வெகுஜனஊடகத்துறை அமைச்சு தகவல் மாதத்தை பிரகடனப்படுத்தியுள்ளது. இம் மாதம் 15 ஆம் திகதி தொடக்கம் அடுத்த மாதம் 15 ஆம் திகதி வரையில் இடம்பெறும். தகவல் அறிந்து கொள்ளும் உரிமை குறித்து செயற்படுவதில் ஊக்குவிப்பதற்கான பல வேலைத்திட்டங்கள் இக் காலப்பகுதியில் நடைமுறைப்படுத்தப்படும். இலங்கையில் 2016 ஆம் ஆண்டில் தகவல்களை அறிந்து கொள்ளும் சட்டம் பாராளுமன்றத்தில் நிறை வேற்றப்படும். ஜனநாயகத்தை மேலும் வலுப்படுத்தும் நடவடிக்கையாக இது இடம்பெற்றள்ளது. தற்பொழுது இந்த சட்டம் உலகத்தில் நான்காவது சட்டமாக தரப்படுத்தப்பட்டுள்ளது. டெல்லியில் உள்ள பாஜக தலைமையகத்தில் பிளாஸ்டிக் பொருட்களின் பயன்பாடு தடை செய்யப்பட்டுள்ளது. அங்கு வாட்டர் பாட்டில் போன்ற ஒருமுறை பயன்படுத்தக்கூடிய பிளாஸ்டிக் பொருட்கள் தடை செய்யப்பட்டுள்ளது. இந்தியா தற்போது அடுத்த தேர்தல் பரபரப்பிற்கு தயாராகி வருகிறது.
# Pred: The International Information Day is today. This has been scheduled by the previous State Security Information Month. This May 15th begins on the next May 15th will be held on the next May 15th. A number of workshops on the publication in the practice of the right to know information will be carried out in this period. The goal is to get information in 2016 will be completed in the National Security Council. This has been placed on the action of further marketing of democracy. This plan will be legally registered in the world. The main platform on the Internet has been used for the use of platforms such as platforms. The next year will be used for the use of platforms such as platforms.
# Ref: Today is the International day for access to information. On account of this, the Ministry of Public media department has announced Information month. This will be held from the 15th of this month until the 15th of next month. During this period many programs to encourage actions regarding the right to access information will be implemented. The law to access information will be passed in the Sri Lankan parliament in 2016. This activity will further strengthen democracy. This law is currently ranked as the fourth of its kind in the world. Usage of plastic products banned at BJP headquarters in Delhi. The usage of single use plastic products like water bottles is banned there. India is getting ready for the busy elections.

# %% [markdown]
# Conclusions:
# - The mappings perturbate performance by ~3% on average - Notable changes are:
#   - Khmer (The language uses almost no punctuation so nothing gets split)
#   - Gujarati (Same problem as Khmer)
#   - Korean (~5% degradation)
#
# - The language mapped to makes only a small difference, as pySBD applies very few language-specific splits (See ablations below)
#
# - Results are sometimes better for the PySBD versions, since texts in the dataset logically follow each other, so squashing them together and setting the boundaries differently might help the model. (We could randomize the order, but this is more likely of a real-world scenario where text in a row is related)

# %% [markdown]
# ###### KHMER
#
# It doesn't matter - Khmer seems to never gets tokenized as it hardly contains Punctuation. The same is likely true for Thai & Laos.

# %%
# Baseline

# !python main.py --model m2m --weights facebook/m2m100_418M --data km-en --sample 500 --baseline
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from km to en.
# Mapped km to en
# Baseline: Preds reduced to 100 samples with 5 sentences each.
# Baseline: Target reduced to 100 samples with 5 sentences each.
# Mapped km to en
# Scored 2.8700016499755345 on language pair km-en.
# 100% 1/1 [04:58<00:00, 298.80s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# km-en
#
# BLEU
# 2.8700016499755345
#
# AVG SPEED
# 0.5194755063056946
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        45.04%        2.065s        45.04%        2.065s      29.231us       0.000us         0.00%       0.000us       0.000us         70653
#                                      aten::index_select         1.66%      76.217ms        37.23%        1.707s     258.411us     124.934ms         7.20%     124.934ms      18.915us          6605
#                                         aten::embedding         0.03%       1.266ms        33.65%        1.543s      11.598ms       0.000us         0.00%       1.383ms      10.398us           133
#                                            aten::linear         1.68%      77.099ms        19.46%     892.116ms      69.156us       0.000us         0.00%     865.612ms      67.102us         12900
#                                         cudaMemcpyAsync        15.02%     688.517ms        15.02%     688.517ms     198.420us       0.000us         0.00%       0.000us       0.000us          3470
#                                              aten::item         0.07%       2.996ms        14.87%     681.549ms     563.264us       0.000us         0.00%       1.199ms       0.991us          1210
#                               aten::_local_scalar_dense         0.16%       7.290ms        14.80%     678.613ms     560.837us       1.210ms         0.07%       1.210ms       1.000us          1210
#                                        aten::is_nonzero         0.02%     884.000us        14.44%     661.819ms       1.663ms       0.000us         0.00%     398.000us       1.000us           398
#                                            aten::matmul         1.96%      89.660ms        10.72%     491.265ms      38.083us       0.000us         0.00%     814.921ms      63.172us         12900
#                                                aten::mm         3.60%     164.933ms         7.27%     333.249ms      25.833us     814.921ms        46.93%     814.921ms      63.172us         12900
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 4.585s
# Self CUDA time total: 1.736s
#
#
# EXAMPLE
# Src: អសារកម្មសិទ្ធិ: កម្មសិទ្ធិ ដែលឥតអោយផលដល់ម្ចាស់កម្មសិទ្ធិទេ ដោយហេតុថា ម្ចាស់កម្មសិទ្ធិនោះអោយសិទ្ធិខ្លួនទៅអ្នកដទៃស៊ីផល នៃកម្មសិទ្ធិនេះទាំងអស់ ។ គ្រប់យានជំនិះដែលមានចលនានៅលើផ្លូវថ្នល់ ត្រូវតែមានអ្នកបើកបរ ។ ចេញប័ណ្ណបោះឆ្នោត រឺ វិញ្ញាបនប័ត្រជំនួសប័ណ្ណបោះឆ្នោតមានបិទរូបថតជូនអ្នកសុំចុះឈ្មោះបោះឆ្នោត សេចក្ដីកំជិល កើតជាមន្ទិល ដល់ពណ៌ហ្មងសៅ សេចក្ដីប្រមាថ គឺជាតិសៅដៅ ជាមន្ទិលនៅ នៃអ្នករក្សា ។ នីតិវិធី: វិធី ដែលតុលាការប្រើប្រាស់ ដើម្បីចាត់ចែងរឿងក្ដីតាំងពីដើមរហូតដល់ចប់ ។
# Pred: Thus, the worship of the worship of the worship of the worship of the worship of the worship of the worship of the worship. All trains that are placed on the road must have an open person. Issue: Issue: Issue: Issue: Issue: Issue: Issue: Issue: Issue: Issue They had brought the knowledge of theliving God who ruleth all things.” {E. G. White, Review and Herald, May 3, 1892 par. Method: The method of using it to keep the story from beginning to end.
# Ref: Asavhekamaset: Belongings that doesn't provide benefits to the holder due to the holder relinquishing all the benefits to others. Every vehicle that are moving on the road must have a driver. The election cards or cards to substitute for the election cards with pictures of the people that want to register to vote. Laziness causes doubtfulness, underestimation causes carelessness, which is the doubtfulness of the bearer. Procedures are the way that the courts use to handle the case from the beginning to the end.

# %%
# Mapped to Nothing

# !python main.py --model m2m --weights facebook/m2m100_418M --data km-en --sample 500 --mergesents 10 --nosplitting
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from km to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (480 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (363 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (434 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (403 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (374 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (348 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (365 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (382 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (395 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (344 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (349 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (394 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (371 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (375 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (460 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (368 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (430 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (365 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (437 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (412 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 1.2204897840387359 on language pair km-en.
# 100% 1/1 [03:41<00:00, 221.82s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# km-en
#
# BLEU
# 1.2204897840387359
#
# AVG SPEED
# 3.2134978055953978
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        33.57%        2.383s        33.57%        2.383s      22.148us       0.000us         0.00%       0.000us       0.000us        107616
#                                      aten::index_select         2.18%     155.062ms        25.91%        1.839s     184.779us     471.892ms        12.88%     471.892ms      47.403us          9955
#                                         cudaMemcpyAsync        24.78%        1.759s        24.78%        1.759s     213.829us       0.000us         0.00%       0.000us       0.000us          8228
#                                              aten::item         0.11%       7.579ms        24.57%        1.744s     606.961us       0.000us         0.00%       2.839ms       0.988us          2874
#                               aten::_local_scalar_dense         0.24%      17.028ms        24.46%        1.737s     604.393us       2.875ms         0.08%       2.875ms       1.000us          2874
#                                        aten::is_nonzero         0.03%       2.027ms        23.89%        1.696s       1.840ms       0.000us         0.00%     922.000us       1.000us           922
#                                         aten::embedding         0.03%       1.908ms        21.88%        1.554s       7.768ms       0.000us         0.00%       2.922ms      14.610us           200
#                                            aten::linear         1.71%     121.311ms        20.56%        1.460s      75.267us       0.000us         0.00%        1.328s      68.482us         19399
#                                            aten::matmul         1.99%     141.007ms        10.74%     762.897ms      39.327us       0.000us         0.00%        1.250s      64.456us         19399
#                                                aten::mm         3.44%     243.988ms         7.13%     506.300ms      26.099us        1.250s        34.13%        1.250s      64.456us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.100s
# Self CUDA time total: 3.664s
#
#
# EXAMPLE
# Src: អសារកម្មសិទ្ធិ: កម្មសិទ្ធិ ដែលឥតអោយផលដល់ម្ចាស់កម្មសិទ្ធិទេ ដោយហេតុថា ម្ចាស់កម្មសិទ្ធិនោះអោយសិទ្ធិខ្លួនទៅអ្នកដទៃស៊ីផល នៃកម្មសិទ្ធិនេះទាំងអស់ ។ គ្រប់យានជំនិះដែលមានចលនានៅលើផ្លូវថ្នល់ ត្រូវតែមានអ្នកបើកបរ ។ ចេញប័ណ្ណបោះឆ្នោត រឺ វិញ្ញាបនប័ត្រជំនួសប័ណ្ណបោះឆ្នោតមានបិទរូបថតជូនអ្នកសុំចុះឈ្មោះបោះឆ្នោត សេចក្ដីកំជិល កើតជាមន្ទិល ដល់ពណ៌ហ្មងសៅ សេចក្ដីប្រមាថ គឺជាតិសៅដៅ ជាមន្ទិលនៅ នៃអ្នករក្សា ។ នីតិវិធី: វិធី ដែលតុលាការប្រើប្រាស់ ដើម្បីចាត់ចែងរឿងក្ដីតាំងពីដើមរហូតដល់ចប់ ។ ផ្ញើទំរង់បែបបទបដិសេធ ជូនគណកម្មការខេត្ត ក្រុងរៀបចំការបោះឆ្នោតមួយច្បាប់ និង រក្សា ទុកជាអែកសារមួយច្បាប់ ។ ល្មមទៅល្មមខាន ល្មមដើរបំពាន កុំគិតត្រង់ងាយ ល្មមគិតបង្អង់ ល្មមខានទៅអាយក្ដីក្រកុំស្រាយ ក្ដីងាយកុំធ្វេស ។ ក្នុងករណីចាំបាច់ ក្រសួងមហាផៃ្ទមានសិទ្ធិត្រួតពិនិត្យគ្រប់សាលារៀនបើកបរឯកជនទាំងអស់ ។ គណកម្មាធិការជាតិរៀបចំការបោះឆ្នោតត្រូវធានាផ្តល់ហិបឆ្នោតអោយបានគ្រប់ចំនួនសំរាប់ឃុំ សង្កាត់នីមួយៗ ។ គ្រប់ហិប ឆ្នោតទាំងអស់ត្រូវ: * មានគម្របជាប់ជាមួយ បុរាណចាយចែង សម្ដីសម្ដែង ទុកតវែងឆ្ងាយ សម្រាប់កូនចៅ ញាតិផៅទាំងឡាយតែងប្រែអធិប្បាយ តាមចិត្តចំណង់ ។
# Pred: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Propert Related Topics: Faith  Faith as a Function of Prayer  Faith as Gift of God  Faith, Living  Fasting  Loyalty  Prayer  Prayer as Contact with God  Prayer as Conversation  Prayer as Fellowship  Prayer's Purpose  Prayer, Effectiveness in  Prayer, Power of  Praying Always  Praying at All Times  Praying without Ceasing  Relationship with God  Trust
# Ref: Asavhekamaset: Belongings that doesn't provide benefits to the holder due to the holder relinquishing all the benefits to others. Every vehicle that are moving on the road must have a driver. The election cards or cards to substitute for the election cards with pictures of the people that want to register to vote. Laziness causes doubtfulness, underestimation causes carelessness, which is the doubtfulness of the bearer. Procedures are the way that the courts use to handle the case from the beginning to the end. Send the rejection notice to all election agencies in all cities and provinces one copy each and keep one for the record. Better to go, better to stay, better to breach, don't think too straightforward, better to slow down, better to go there, don't procrastinate with few cases, don't be careless with easy cases. When necessary, Ministry of Interior has the right to inspect every private driving school. The national agency of election must guarantee that each office must have enough voting cases. Each voting case must: have a cover coming with it. The ancient people narrated and passed on for their kids and relatives to interpret according to their desires.

# %%
# Mapped to Burmese

# !python main.py --model m2m --weights facebook/m2m100_418M --data km-en --sample 500 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from km to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped km to my
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (480 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (403 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (374 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (348 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (365 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (382 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (395 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (344 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (349 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (394 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (371 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (375 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (460 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (368 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (430 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (339 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (437 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (412 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped km to my
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 1.0939042151712026 on language pair km-en.
# 100% 1/1 [03:46<00:00, 226.75s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# km-en
#
# BLEU
# 1.0939042151712026
#
# AVG SPEED
# 3.319175748825073
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        33.45%        2.347s        33.45%        2.347s      21.812us       0.000us         0.00%       0.000us       0.000us        107616
#                                      aten::index_select         2.17%     152.475ms        25.80%        1.811s     181.889us     471.781ms        12.88%     471.781ms      47.391us          9955
#                                         cudaMemcpyAsync        25.17%        1.767s        25.17%        1.767s     214.709us       0.000us         0.00%       0.000us       0.000us          8228
#                                              aten::item         0.11%       7.439ms        24.95%        1.751s     609.180us       0.000us         0.00%       2.867ms       0.998us          2874
#                               aten::_local_scalar_dense         0.23%      16.400ms        24.84%        1.743s     606.645us       2.897ms         0.08%       2.897ms       1.008us          2874
#                                        aten::is_nonzero         0.03%       2.028ms        24.28%        1.704s       1.848ms       0.000us         0.00%     922.000us       1.000us           922
#                                         aten::embedding         0.03%       1.878ms        21.80%        1.530s       7.650ms       0.000us         0.00%       2.917ms      14.585us           200
#                                            aten::linear         1.67%     117.534ms        20.45%        1.435s      73.982us       0.000us         0.00%        1.329s      68.490us         19399
#                                            aten::matmul         1.97%     138.604ms        10.65%     747.338ms      38.525us       0.000us         0.00%        1.251s      64.496us         19399
#                                                aten::mm         3.43%     240.805ms         7.06%     495.320ms      25.533us        1.251s        34.15%        1.251s      64.496us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.018s
# Self CUDA time total: 3.664s
#
#
# EXAMPLE
# Src: អសារកម្មសិទ្ធិ: កម្មសិទ្ធិ ដែលឥតអោយផលដល់ម្ចាស់កម្មសិទ្ធិទេ ដោយហេតុថា ម្ចាស់កម្មសិទ្ធិនោះអោយសិទ្ធិខ្លួនទៅអ្នកដទៃស៊ីផល នៃកម្មសិទ្ធិនេះទាំងអស់ ។ គ្រប់យានជំនិះដែលមានចលនានៅលើផ្លូវថ្នល់ ត្រូវតែមានអ្នកបើកបរ ។ ចេញប័ណ្ណបោះឆ្នោត រឺ វិញ្ញាបនប័ត្រជំនួសប័ណ្ណបោះឆ្នោតមានបិទរូបថតជូនអ្នកសុំចុះឈ្មោះបោះឆ្នោត សេចក្ដីកំជិល កើតជាមន្ទិល ដល់ពណ៌ហ្មងសៅ សេចក្ដីប្រមាថ គឺជាតិសៅដៅ ជាមន្ទិលនៅ នៃអ្នករក្សា ។ នីតិវិធី: វិធី ដែលតុលាការប្រើប្រាស់ ដើម្បីចាត់ចែងរឿងក្ដីតាំងពីដើមរហូតដល់ចប់ ។ ផ្ញើទំរង់បែបបទបដិសេធ ជូនគណកម្មការខេត្ត ក្រុងរៀបចំការបោះឆ្នោតមួយច្បាប់ និង រក្សា ទុកជាអែកសារមួយច្បាប់ ។ ល្មមទៅល្មមខាន ល្មមដើរបំពាន កុំគិតត្រង់ងាយ ល្មមគិតបង្អង់ ល្មមខានទៅអាយក្ដីក្រកុំស្រាយ ក្ដីងាយកុំធ្វេស ។ ក្នុងករណីចាំបាច់ ក្រសួងមហាផៃ្ទមានសិទ្ធិត្រួតពិនិត្យគ្រប់សាលារៀនបើកបរឯកជនទាំងអស់ ។ គណកម្មាធិការជាតិរៀបចំការបោះឆ្នោតត្រូវធានាផ្តល់ហិបឆ្នោតអោយបានគ្រប់ចំនួនសំរាប់ឃុំ សង្កាត់នីមួយៗ ។ គ្រប់ហិប ឆ្នោតទាំងអស់ត្រូវ: * មានគម្របជាប់ជាមួយ បុរាណចាយចែង សម្ដីសម្ដែង ទុកតវែងឆ្ងាយ សម្រាប់កូនចៅ ញាតិផៅទាំងឡាយតែងប្រែអធិប្បាយ តាមចិត្តចំណង់ ។
# Pred: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Propert Related Topics: Faith  Faith as a Function of Prayer  Faith as Gift of God  Faith, Living  Fasting  Loyalty  Prayer  Prayer as Contact with God  Prayer as Conversation  Prayer as Fellowship  Prayer's Purpose  Prayer, Effectiveness in  Prayer, Power of  Praying Always  Praying at All Times  Praying without Ceasing  Relationship with God  Trust
# Ref: Asavhekamaset: Belongings that doesn't provide benefits to the holder due to the holder relinquishing all the benefits to others. Every vehicle that are moving on the road must have a driver. The election cards or cards to substitute for the election cards with pictures of the people that want to register to vote. Laziness causes doubtfulness, underestimation causes carelessness, which is the doubtfulness of the bearer. Procedures are the way that the courts use to handle the case from the beginning to the end. Send the rejection notice to all election agencies in all cities and provinces one copy each and keep one for the record. Better to go, better to stay, better to breach, don't think too straightforward, better to slow down, better to go there, don't procrastinate with few cases, don't be careless with easy cases. When necessary, Ministry of Interior has the right to inspect every private driving school. The national agency of election must guarantee that each office must have enough voting cases. Each voting case must: have a cover coming with it. The ancient people narrated and passed on for their kids and relatives to interpret according to their desires.

# %%
# Mapped to English

# !python main.py --model m2m --weights facebook/m2m100_418M --data km-en --sample 500 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from km to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped km to en
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (480 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (403 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (374 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (348 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (322 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (365 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (382 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (395 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (387 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (344 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (349 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (414 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (394 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (371 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (375 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (460 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (404 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (378 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (368 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (430 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (339 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (400 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (353 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (410 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (437 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (412 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (369 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped km to en
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 1.0939042151712026 on language pair km-en.
# 100% 1/1 [03:46<00:00, 226.61s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# km-en
#
# BLEU
# 1.0939042151712026
#
# AVG SPEED
# 3.3152192783355714
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        33.58%        2.342s        33.58%        2.342s      21.762us       0.000us         0.00%       0.000us       0.000us        107616
#                                      aten::index_select         2.17%     150.991ms        25.94%        1.809s     181.733us     471.766ms        12.88%     471.766ms      47.390us          9955
#                                         cudaMemcpyAsync        25.34%        1.767s        25.34%        1.767s     214.810us       0.000us         0.00%       0.000us       0.000us          8228
#                                              aten::item         0.10%       7.214ms        25.14%        1.753s     609.982us       0.000us         0.00%       2.868ms       0.998us          2874
#                               aten::_local_scalar_dense         0.23%      16.330ms        25.04%        1.746s     607.536us       2.907ms         0.08%       2.907ms       1.011us          2874
#                                        aten::is_nonzero         0.03%       2.031ms        24.47%        1.706s       1.851ms       0.000us         0.00%     954.000us       1.035us           922
#                                         aten::embedding         0.03%       1.876ms        21.91%        1.528s       7.641ms       0.000us         0.00%       2.936ms      14.680us           200
#                                            aten::linear         1.63%     113.879ms        20.30%        1.415s      72.964us       0.000us         0.00%        1.328s      68.437us         19399
#                                            aten::matmul         2.00%     139.768ms        10.63%     741.221ms      38.209us       0.000us         0.00%        1.250s      64.411us         19399
#                                                aten::mm         3.40%     237.270ms         7.06%     492.301ms      25.378us        1.250s        34.12%        1.250s      64.411us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.974s
# Self CUDA time total: 3.662s
#
#
# EXAMPLE
# Src: អសារកម្មសិទ្ធិ: កម្មសិទ្ធិ ដែលឥតអោយផលដល់ម្ចាស់កម្មសិទ្ធិទេ ដោយហេតុថា ម្ចាស់កម្មសិទ្ធិនោះអោយសិទ្ធិខ្លួនទៅអ្នកដទៃស៊ីផល នៃកម្មសិទ្ធិនេះទាំងអស់ ។ គ្រប់យានជំនិះដែលមានចលនានៅលើផ្លូវថ្នល់ ត្រូវតែមានអ្នកបើកបរ ។ ចេញប័ណ្ណបោះឆ្នោត រឺ វិញ្ញាបនប័ត្រជំនួសប័ណ្ណបោះឆ្នោតមានបិទរូបថតជូនអ្នកសុំចុះឈ្មោះបោះឆ្នោត សេចក្ដីកំជិល កើតជាមន្ទិល ដល់ពណ៌ហ្មងសៅ សេចក្ដីប្រមាថ គឺជាតិសៅដៅ ជាមន្ទិលនៅ នៃអ្នករក្សា ។ នីតិវិធី: វិធី ដែលតុលាការប្រើប្រាស់ ដើម្បីចាត់ចែងរឿងក្ដីតាំងពីដើមរហូតដល់ចប់ ។ ផ្ញើទំរង់បែបបទបដិសេធ ជូនគណកម្មការខេត្ត ក្រុងរៀបចំការបោះឆ្នោតមួយច្បាប់ និង រក្សា ទុកជាអែកសារមួយច្បាប់ ។ ល្មមទៅល្មមខាន ល្មមដើរបំពាន កុំគិតត្រង់ងាយ ល្មមគិតបង្អង់ ល្មមខានទៅអាយក្ដីក្រកុំស្រាយ ក្ដីងាយកុំធ្វេស ។ ក្នុងករណីចាំបាច់ ក្រសួងមហាផៃ្ទមានសិទ្ធិត្រួតពិនិត្យគ្រប់សាលារៀនបើកបរឯកជនទាំងអស់ ។ គណកម្មាធិការជាតិរៀបចំការបោះឆ្នោតត្រូវធានាផ្តល់ហិបឆ្នោតអោយបានគ្រប់ចំនួនសំរាប់ឃុំ សង្កាត់នីមួយៗ ។ គ្រប់ហិប ឆ្នោតទាំងអស់ត្រូវ: * មានគម្របជាប់ជាមួយ បុរាណចាយចែង សម្ដីសម្ដែង ទុកតវែងឆ្ងាយ សម្រាប់កូនចៅ ញាតិផៅទាំងឡាយតែងប្រែអធិប្បាយ តាមចិត្តចំណង់ ។
# Pred: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Propert Related Topics: Faith  Faith as a Function of Prayer  Faith as Gift of God  Faith, Living  Fasting  Loyalty  Prayer  Prayer as Contact with God  Prayer as Conversation  Prayer as Fellowship  Prayer's Purpose  Prayer, Effectiveness in  Prayer, Power of  Praying Always  Praying at All Times  Praying without Ceasing  Relationship with God  Trust
# Ref: Asavhekamaset: Belongings that doesn't provide benefits to the holder due to the holder relinquishing all the benefits to others. Every vehicle that are moving on the road must have a driver. The election cards or cards to substitute for the election cards with pictures of the people that want to register to vote. Laziness causes doubtfulness, underestimation causes carelessness, which is the doubtfulness of the bearer. Procedures are the way that the courts use to handle the case from the beginning to the end. Send the rejection notice to all election agencies in all cities and provinces one copy each and keep one for the record. Better to go, better to stay, better to breach, don't think too straightforward, better to slow down, better to go there, don't procrastinate with few cases, don't be careless with easy cases. When necessary, Ministry of Interior has the right to inspect every private driving school. The national agency of election must guarantee that each office must have enough voting cases. Each voting case must: have a cover coming with it. The ancient people narrated and passed on for their kids and relatives to interpret according to their desires.

# %%
# Mapped to Chinese

# !python main.py --model m2m --weights facebook/m2m100_418M --data km-en --sample 100 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from km to en.
# Benchmarking: Source reduced to 10 samples with 10 sentences each.
# Benchmarking: Target reduced to 10 samples with 10 sentences each.
# Mapped km to zh
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (480 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (334 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (373 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (367 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (408 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (426 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (403 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped km to zh
# Sentence is too long (407 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 1.5050749936281183 on language pair km-en.
# 100% 1/1 [01:38<00:00, 98.42s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# km-en
#
# BLEU
# 1.5050749936281183
#
# AVG SPEED
# 3.592610549926758
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        34.10%        2.433s        34.10%        2.433s      22.606us       0.000us         0.00%       0.000us       0.000us        107616
#                                      aten::index_select         2.14%     152.931ms        26.24%        1.872s     188.066us     470.505ms        12.83%     470.505ms      47.263us          9955
#                                         cudaMemcpyAsync        24.59%        1.755s        24.59%        1.755s     213.243us       0.000us         0.00%       0.000us       0.000us          8228
#                                              aten::item         0.11%       7.626ms        24.37%        1.739s     604.935us       0.000us         0.00%       2.848ms       0.991us          2874
#                               aten::_local_scalar_dense         0.24%      17.405ms        24.26%        1.731s     602.333us       2.875ms         0.08%       2.875ms       1.000us          2874
#                                        aten::is_nonzero         0.03%       2.206ms        23.65%        1.688s       1.830ms       0.000us         0.00%     922.000us       1.000us           922
#                                         aten::embedding         0.03%       2.172ms        22.26%        1.589s       7.943ms       0.000us         0.00%       2.787ms      13.935us           200
#                                            aten::linear         1.67%     118.987ms        20.48%        1.461s      75.322us       0.000us         0.00%        1.326s      68.372us         19399
#                                            aten::matmul         1.98%     141.285ms        10.71%     764.191ms      39.393us       0.000us         0.00%        1.249s      64.363us         19399
#                                                aten::mm         3.45%     246.477ms         7.13%     508.861ms      26.231us        1.249s        34.05%        1.249s      64.363us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.135s
# Self CUDA time total: 3.667s
#
#
# EXAMPLE
# Src: អសារកម្មសិទ្ធិ: កម្មសិទ្ធិ ដែលឥតអោយផលដល់ម្ចាស់កម្មសិទ្ធិទេ ដោយហេតុថា ម្ចាស់កម្មសិទ្ធិនោះអោយសិទ្ធិខ្លួនទៅអ្នកដទៃស៊ីផល នៃកម្មសិទ្ធិនេះទាំងអស់ ។ គ្រប់យានជំនិះដែលមានចលនានៅលើផ្លូវថ្នល់ ត្រូវតែមានអ្នកបើកបរ ។ ចេញប័ណ្ណបោះឆ្នោត រឺ វិញ្ញាបនប័ត្រជំនួសប័ណ្ណបោះឆ្នោតមានបិទរូបថតជូនអ្នកសុំចុះឈ្មោះបោះឆ្នោត សេចក្ដីកំជិល កើតជាមន្ទិល ដល់ពណ៌ហ្មងសៅ សេចក្ដីប្រមាថ គឺជាតិសៅដៅ ជាមន្ទិលនៅ នៃអ្នករក្សា ។ នីតិវិធី: វិធី ដែលតុលាការប្រើប្រាស់ ដើម្បីចាត់ចែងរឿងក្ដីតាំងពីដើមរហូតដល់ចប់ ។ ផ្ញើទំរង់បែបបទបដិសេធ ជូនគណកម្មការខេត្ត ក្រុងរៀបចំការបោះឆ្នោតមួយច្បាប់ និង រក្សា ទុកជាអែកសារមួយច្បាប់ ។ ល្មមទៅល្មមខាន ល្មមដើរបំពាន កុំគិតត្រង់ងាយ ល្មមគិតបង្អង់ ល្មមខានទៅអាយក្ដីក្រកុំស្រាយ ក្ដីងាយកុំធ្វេស ។ ក្នុងករណីចាំបាច់ ក្រសួងមហាផៃ្ទមានសិទ្ធិត្រួតពិនិត្យគ្រប់សាលារៀនបើកបរឯកជនទាំងអស់ ។ គណកម្មាធិការជាតិរៀបចំការបោះឆ្នោតត្រូវធានាផ្តល់ហិបឆ្នោតអោយបានគ្រប់ចំនួនសំរាប់ឃុំ សង្កាត់នីមួយៗ ។ គ្រប់ហិប ឆ្នោតទាំងអស់ត្រូវ: * មានគម្របជាប់ជាមួយ បុរាណចាយចែង សម្ដីសម្ដែង ទុកតវែងឆ្ងាយ សម្រាប់កូនចៅ ញាតិផៅទាំងឡាយតែងប្រែអធិប្បាយ តាមចិត្តចំណង់ ។
# Pred: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Property: Propert Related Topics: Faith  Faith as a Function of Prayer  Faith as Gift of God  Faith, Living  Fasting  Loyalty  Prayer  Prayer as Contact with God  Prayer as Conversation  Prayer as Fellowship  Prayer's Purpose  Prayer, Effectiveness in  Prayer, Power of  Praying Always  Praying at All Times  Praying without Ceasing  Relationship with God  Trust
# Ref: Asavhekamaset: Belongings that doesn't provide benefits to the holder due to the holder relinquishing all the benefits to others. Every vehicle that are moving on the road must have a driver. The election cards or cards to substitute for the election cards with pictures of the people that want to register to vote. Laziness causes doubtfulness, underestimation causes carelessness, which is the doubtfulness of the bearer. Procedures are the way that the courts use to handle the case from the beginning to the end. Send the rejection notice to all election agencies in all cities and provinces one copy each and keep one for the record. Better to go, better to stay, better to breach, don't think too straightforward, better to slow down, better to go there, don't procrastinate with few cases, don't be careless with easy cases. When necessary, Ministry of Interior has the right to inspect every private driving school. The national agency of election must guarantee that each office must have enough voting cases. Each voting case must: have a cover coming with it. The ancient people narrated and passed on for their kids and relatives to interpret according to their desires.

# %% [markdown]
# ###### GUJARATI
#
# Swapping Hindi / Urdu makes no difference.
# The baseline is likely worse because the splitters split almost nothing & it seems subsequent sentences are related to each other, so the translator performs better when seeing more of that.

# %%
# Baseline

# !python main.py --model m2m --weights facebook/m2m100_418M --data gu-en --sample 100 --baseline --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from gu to en.
# Baseline: Preds reduced to 10 samples with 10 sentences each.
# Baseline: Target reduced to 10 samples with 10 sentences each.
# Scored 0.17565088682203797 on language pair gu-en.
# 100% 1/1 [01:48<00:00, 108.52s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# gu-en
#
# BLEU
# 0.17565088682203797
#
# AVG SPEED
# 0.7915417242050171
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        52.46%        1.967s        52.46%        1.967s      38.601us       0.000us         0.00%       0.000us       0.000us         50969
#                                      aten::index_select         1.48%      55.433ms        45.01%        1.688s     355.019us      99.659ms         7.77%      99.659ms      20.959us          4755
#                                         aten::embedding         0.03%     954.000us        41.77%        1.566s      16.316ms       0.000us         0.00%       1.025ms      10.677us            96
#                                            aten::linear         1.50%      56.119ms        17.55%     658.142ms      70.684us       0.000us         0.00%     633.826ms      68.073us          9311
#                                         cudaMemcpyAsync        13.23%     496.156ms        13.23%     496.156ms     197.829us       0.000us         0.00%       0.000us       0.000us          2508
#                                              aten::item         0.06%       2.256ms        13.12%     492.091ms     561.107us       0.000us         0.00%     873.000us       0.995us           877
#                               aten::_local_scalar_dense         0.17%       6.383ms        13.06%     489.865ms     558.569us     878.000us         0.07%     878.000us       1.001us           877
#                                        aten::is_nonzero         0.02%     708.000us        12.74%     477.729ms       1.665ms       0.000us         0.00%     288.000us       1.003us           287
#                                            aten::matmul         1.75%      65.557ms         9.75%     365.614ms      39.267us       0.000us         0.00%     596.399ms      64.053us          9311
#                                                aten::mm         3.20%     119.931ms         6.68%     250.448ms      26.898us     596.399ms        46.48%     596.399ms      64.053us          9311
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 3.750s
# Self CUDA time total: 1.283s
#
#
# EXAMPLE
# Src: પતંજલી લોટના પેકેટમાં નિક્ળ્યો દેડકો, સુપર બાજારથી ખરીદયું હતું લોટ મધ્યપ્રદેશના સીહોરમાં પંતજલીના લોટ પેકેટમાં મરેલું દેડકો મળવાની ખબર આવી છે. આ લોટ અહીંના એક સુપર બાજારથી ખરીદયો હતો. સૂત્રોએ મળી જાણકારી મુજબ અવધપુરી નિવાસી બલવંતસિંહ નામનો માણસ દ્વારા શહરના ચાણ્કયપુરી સ્થિત સુઓઅરના પતંજલી સ્ટોરથી 5 કિલોનો લોટ પેકેટનો ખરીદયો જેની પેકિંગ ખરીદીના સમયે ઠીક હતી. બલવંતના ઘરવાળા તે લોટ ઉપયોગ પણ કરી રહ્યા હતા. પણ તે વચ્ચે એક દિવસ લોટમાં કઈકે વસ્તુ સ્પર્શ થઈ. જ્યરે તેને જોયું તો તેના હોંશ ઉડી ગયા. તે લોટમાંથી ત્રણ મરેલા દેડકા નિક્ળ્યા. ઘટનાની જાણકારી મળતા જ ઘરે જોવાવાળાનો જમાવડો લાગી ગયું. આ પતંજલીના સ્ટોરથી જ ખરીદ્યું હતું.
# Pred: (تيْحي أَمثَان سُورِيُويْتو) (لسنا بمجتري هواء نفثه) أي: حين ننشدها، فليس معنى أننا نحاكيه بإنشاده أن نأخذ الهواء الذي نفثه ونعيده نحن حتى نخرجه مرة أخرى كما أخرجه هو. (تيْحي أَمثَان سُورِيُويْتو) In the meantime, it’s a good thing to be able to do, and it’s a good thing to be able to do, and it’s a good thing to be able to do, and it’s a good thing to be able to do, and it’s a good thing to be able to do, and it’s a good thing to be able to do. (تيْحي أَمثَان سُورِيُويْتو) (لسنا بمجتري هواء نفثه) أي: حين ننشدها، فليس معنى أننا نحاكيه بإنشاده أن نأخذ الهواء الذي نفثه ونعيده نحن حتى نخرجه هو. (تيْحي أَمثَان سُورِيُويْتو) (تيْحي أَمثَان سُورِيُويْتو) (لسنا بمجتري هواء نفثه) أي: حين ننشدها، فليس معنى أننا نحاكيه بإنشاده أن نأخذ الهواء الذي نفثه ونعيده نحن حتى نخرجه مرة أخرى كما أخرجه هو. (تيْحي أَمثَان سُورِيُويْتو)
# Ref: Frog inside Patanjali ‘Aata’ (flour) packet, was purchased from the Super Bazaar. There is news that a dead frog was found in a Patanjali Aata packet in Sehore district of Madhya Pradesh. This flour was bought from Super Bazaar. According to sources, a person named Balvant Singh, an Awadhpuri resident bought a 5kg flour packet from Patanjali store in Sehore, whose packing was okay at the time of purchase. Balwant’s family were also using the flour. But someone felt something in the flour one day. When he was what it was, he was shocked. Three dead frogs were seen in the flour packet. As people came to know of this, they started gathering to see this spectacle. This was bought from Patanjali Store itself.

# %%
# Hindi

# !python main.py --model m2m --weights facebook/m2m100_418M --data gu-en --sample 100 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from gu to en.
# Benchmarking: Source reduced to 10 samples with 10 sentences each.
# Benchmarking: Target reduced to 10 samples with 10 sentences each.
# Mapped gu to hi
# Sentence is too long (338 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (314 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (374 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (399 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (340 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (444 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (392 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped gu to hi
# Scored 2.672712662530038 on language pair gu-en.
# 100% 1/1 [01:02<00:00, 62.58s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# gu-en
#
# BLEU
# 2.672712662530038
#
# AVG SPEED
# 3.315636992454529
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        52.35%        1.976s        52.35%        1.976s      38.774us       0.000us         0.00%       0.000us       0.000us         50969
#                                      aten::index_select         1.43%      53.881ms        45.23%        1.707s     359.053us      99.409ms         7.75%      99.409ms      20.906us          4755
#                                         aten::embedding         0.03%     963.000us        42.04%        1.587s      16.530ms       0.000us         0.00%     881.000us       9.177us            96
#                                            aten::linear         1.47%      55.595ms        17.37%     655.790ms      70.432us       0.000us         0.00%     635.052ms      68.204us          9311
#                                         cudaMemcpyAsync        13.15%     496.480ms        13.15%     496.480ms     197.959us       0.000us         0.00%       0.000us       0.000us          2508
#                                              aten::item         0.06%       2.256ms        13.01%     491.183ms     560.072us       0.000us         0.00%     874.000us       0.997us           877
#                               aten::_local_scalar_dense         0.15%       5.745ms        12.95%     488.935ms     557.509us     876.000us         0.07%     876.000us       0.999us           877
#                                        aten::is_nonzero         0.02%     666.000us        12.61%     476.098ms       1.659ms       0.000us         0.00%     287.000us       1.000us           287
#                                            aten::matmul         1.75%      66.152ms         9.65%     364.153ms      39.110us       0.000us         0.00%     597.672ms      64.190us          9311
#                                                aten::mm         3.30%     124.553ms         6.58%     248.232ms      26.660us     597.672ms        46.60%     597.672ms      64.190us          9311
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 3.775s
# Self CUDA time total: 1.283s
#
#
# EXAMPLE
# Src: પતંજલી લોટના પેકેટમાં નિક્ળ્યો દેડકો, સુપર બાજારથી ખરીદયું હતું લોટ મધ્યપ્રદેશના સીહોરમાં પંતજલીના લોટ પેકેટમાં મરેલું દેડકો મળવાની ખબર આવી છે. આ લોટ અહીંના એક સુપર બાજારથી ખરીદયો હતો. સૂત્રોએ મળી જાણકારી મુજબ અવધપુરી નિવાસી બલવંતસિંહ નામનો માણસ દ્વારા શહરના ચાણ્કયપુરી સ્થિત સુઓઅરના પતંજલી સ્ટોરથી 5 કિલોનો લોટ પેકેટનો ખરીદયો જેની પેકિંગ ખરીદીના સમયે ઠીક હતી. બલવંતના ઘરવાળા તે લોટ ઉપયોગ પણ કરી રહ્યા હતા. પણ તે વચ્ચે એક દિવસ લોટમાં કઈકે વસ્તુ સ્પર્શ થઈ. જ્યરે તેને જોયું તો તેના હોંશ ઉડી ગયા. તે લોટમાંથી ત્રણ મરેલા દેડકા નિક્ળ્યા. ઘટનાની જાણકારી મળતા જ ઘરે જોવાવાળાનો જમાવડો લાગી ગયું. આ પતંજલીના સ્ટોરથી જ ખરીદ્યું હતું.
# Pred: For example, if you want to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out what to do.
# Ref: Frog inside Patanjali ‘Aata’ (flour) packet, was purchased from the Super Bazaar. There is news that a dead frog was found in a Patanjali Aata packet in Sehore district of Madhya Pradesh. This flour was bought from Super Bazaar. According to sources, a person named Balvant Singh, an Awadhpuri resident bought a 5kg flour packet from Patanjali store in Sehore, whose packing was okay at the time of purchase. Balwant’s family were also using the flour. But someone felt something in the flour one day. When he was what it was, he was shocked. Three dead frogs were seen in the flour packet. As people came to know of this, they started gathering to see this spectacle. This was bought from Patanjali Store itself.

# %%
# Urdu

# !python main.py --model m2m --weights facebook/m2m100_418M --data gu-en --sample 100 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from gu to en.
# Benchmarking: Source reduced to 10 samples with 10 sentences each.
# Benchmarking: Target reduced to 10 samples with 10 sentences each.
# Mapped gu to ur
# Sentence is too long (338 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (314 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (374 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (399 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (340 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (416 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (444 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Sentence is too long (392 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Mapped gu to ur
# Scored 2.672712662530038 on language pair gu-en.
# 100% 1/1 [01:02<00:00, 62.03s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# gu-en
#
# BLEU
# 2.672712662530038
#
# AVG SPEED
# 3.3116008043289185
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        52.38%        1.972s        52.38%        1.972s      38.687us       0.000us         0.00%       0.000us       0.000us         50969
#                                      aten::index_select         1.43%      53.918ms        45.08%        1.697s     356.877us      99.603ms         7.77%      99.603ms      20.947us          4755
#                                         aten::embedding         0.03%       1.002ms        41.90%        1.578s      16.432ms       0.000us         0.00%     982.000us      10.229us            96
#                                            aten::linear         1.47%      55.181ms        17.42%     655.762ms      70.429us       0.000us         0.00%     634.885ms      68.187us          9311
#                                         cudaMemcpyAsync        13.18%     496.226ms        13.18%     496.226ms     197.857us       0.000us         0.00%       0.000us       0.000us          2508
#                                              aten::item         0.06%       2.281ms        13.03%     490.690ms     559.510us       0.000us         0.00%     875.000us       0.998us           877
#                               aten::_local_scalar_dense         0.15%       5.579ms        12.97%     488.421ms     556.922us     877.000us         0.07%     877.000us       1.000us           877
#                                        aten::is_nonzero         0.02%     710.000us        12.63%     475.519ms       1.657ms       0.000us         0.00%     288.000us       1.003us           287
#                                            aten::matmul         1.78%      67.101ms         9.62%     362.174ms      38.897us       0.000us         0.00%     597.493ms      64.171us          9311
#                                                aten::mm         3.25%     122.532ms         6.49%     244.486ms      26.258us     597.493ms        46.59%     597.493ms      64.171us          9311
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 3.765s
# Self CUDA time total: 1.283s
#
#
# EXAMPLE
# Src: પતંજલી લોટના પેકેટમાં નિક્ળ્યો દેડકો, સુપર બાજારથી ખરીદયું હતું લોટ મધ્યપ્રદેશના સીહોરમાં પંતજલીના લોટ પેકેટમાં મરેલું દેડકો મળવાની ખબર આવી છે. આ લોટ અહીંના એક સુપર બાજારથી ખરીદયો હતો. સૂત્રોએ મળી જાણકારી મુજબ અવધપુરી નિવાસી બલવંતસિંહ નામનો માણસ દ્વારા શહરના ચાણ્કયપુરી સ્થિત સુઓઅરના પતંજલી સ્ટોરથી 5 કિલોનો લોટ પેકેટનો ખરીદયો જેની પેકિંગ ખરીદીના સમયે ઠીક હતી. બલવંતના ઘરવાળા તે લોટ ઉપયોગ પણ કરી રહ્યા હતા. પણ તે વચ્ચે એક દિવસ લોટમાં કઈકે વસ્તુ સ્પર્શ થઈ. જ્યરે તેને જોયું તો તેના હોંશ ઉડી ગયા. તે લોટમાંથી ત્રણ મરેલા દેડકા નિક્ળ્યા. ઘટનાની જાણકારી મળતા જ ઘરે જોવાવાળાનો જમાવડો લાગી ગયું. આ પતંજલીના સ્ટોરથી જ ખરીદ્યું હતું.
# Pred: For example, if you want to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out how to find out what to do.
# Ref: Frog inside Patanjali ‘Aata’ (flour) packet, was purchased from the Super Bazaar. There is news that a dead frog was found in a Patanjali Aata packet in Sehore district of Madhya Pradesh. This flour was bought from Super Bazaar. According to sources, a person named Balvant Singh, an Awadhpuri resident bought a 5kg flour packet from Patanjali store in Sehore, whose packing was okay at the time of purchase. Balwant’s family were also using the flour. But someone felt something in the flour one day. When he was what it was, he was shocked. Three dead frogs were seen in the flour packet. As people came to know of this, they started gathering to see this spectacle. This was bought from Patanjali Store itself.

# %% [markdown]
# ###### KOREAN
#
# Result: Japanese / Chinese no difference in performance, but both better than English. Likely due to some punctuation marks the English splitting misses.

# %%
# Baseline

# !python main.py --model m2m --weights facebook/m2m100_418M --data ko-en --sample 500 --baseline --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from ko to en.
# Baseline: Preds reduced to 50 samples with 10 sentences each.
# Baseline: Target reduced to 50 samples with 10 sentences each.
# Sentence is too long (303 > 300), and will be translated in pieces, which might degrade performance. Check the source language and/or consider using the 'Split Sentences' option.
# Scored 12.9392389402322 on language pair ko-en.
# 100% 1/1 [03:52<00:00, 232.08s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# ko-en
#
# BLEU
# 12.9392389402322
#
# AVG SPEED
# 0.34565928602218626
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        32.83%        2.450s        32.83%        2.450s      22.792us       0.000us         0.00%       0.000us       0.000us        107501
#                                         cudaMemcpyAsync        28.10%        2.097s        28.10%        2.097s     378.408us       0.000us         0.00%       0.000us       0.000us          5542
#                                              aten::item         0.08%       5.689ms        27.97%        2.087s       1.014ms       0.000us         0.00%       2.039ms       0.990us          2059
#                               aten::_local_scalar_dense         0.17%      12.386ms        27.89%        2.081s       1.011ms       2.064ms         0.05%       2.064ms       1.002us          2059
#                                        aten::is_nonzero         0.03%       1.973ms        27.55%        2.056s       2.554ms       0.000us         0.00%     808.000us       1.004us           805
#                                      aten::index_select         1.89%     141.221ms        25.27%        1.886s     189.427us     446.673ms        11.03%     446.673ms      44.869us          9955
#                                         aten::embedding         0.03%       2.187ms        21.41%        1.598s       7.990ms       0.000us         0.00%       2.920ms      14.600us           200
#                                            aten::linear         1.57%     117.334ms        18.84%        1.406s      72.485us       0.000us         0.00%        1.326s      68.355us         19399
#                                            aten::matmul         2.30%     171.841ms        10.48%     782.192ms      40.321us       0.000us         0.00%        1.249s      64.365us         19399
#                                                aten::mm         3.18%     237.632ms         6.77%     504.922ms      26.028us        1.249s        30.84%        1.249s      64.365us         19399
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.463s
# Self CUDA time total: 4.048s
#
#
# EXAMPLE
# Src: 이 이야기는 우리가 아는 것을 어떻게 아는지에 대한 이야기 입니다. 이 이야기는 이 여성에 대한 이야기 입니다. 나탈리아 리프친스키. 그녀는 고생물학자입니다. 즉, 그녀는 아주 오래 전에 죽은 것들을 파내는데 전문가입니다. 나탈리아 리프친스키: 네 저를 "죽은 것 박사" 라고 부르기도 해요. 라티프 나사: 그리고 제가 그녀에게 관심이 갔던 것은 그녀가 물건을 파내는 곳 때문입니다. 그녀는 북극권 훨씬 위쪽의 외진 캐나다 툰드라 지역에서 일합니다. 2006년의 어느 여름날에 그녀는 Fyles Leaf Bed 라는 발굴 현장에 있었습니다. 자북극에서 위도로 10도도 떨어지지 않은 곳입니다. 나탈리아: 그랬나요? 전혀 대단한 일이 아니었어요. 왜냐면 하루 종일 배낭에 GPS와 노트북을 들고 화석 같아 보이는 건 전부 주우면서 하루종일 걸어 다녔거든요. 라티프:그리고 어느 순간에 그녀는 무언가 깨닫습니다. 나탈리아: 녹슬었어요, 녹슨 것 같은 색깔에 제 손바닥 만한 물건 이었는데. 땅바닥에 그냥 떨어져 있었어요.
# Pred: This is a story about how we know what we know. This is the story of this woman, Natalia Lipchinsky. She’s a pathologist, which means she’s an expert in extinguishing things that were dead a long time ago. Natalia Rifchinsky: You call me “Doctor of the Dead.” Latiff Nasa: And what I was interested in her was because she was leaving things, she works in the outer Canadian Tundra region far above the Arctic. One summer day in 2006 she was in the mining scene called Fyles Leaf Bed, where it was not 10 degrees below the width of the Arctic. Natalya: It wasn’t a great thing at all, because I was walking the whole day with the GPS and the laptop on my backpack and it looked like a fossil. Latiff: And at a moment she realizes something. Nathalie: I was crazy, it was something that I could do with my handheld in a color like Nocson. I was just on the ground.
# Ref: So, this is a story about how we know what we know. It's a story about this woman, Natalia Rybczynski. She's a paleobiologist, which means she specializes in digging up really old dead stuff. Natalia Rybczynski: Yeah, I had someone call me "Dr. Dead Things." Latif Nasser: And I think she's particularly interesting because of where she digs that stuff up, way above the Arctic Circle in the remote Canadian tundra. Now, one summer day in 2006, she was at a dig site called the Fyles Leaf Bed, which is less than 10 degrees latitude away from the magnetic north pole. NR: Really, it's not going to sound very exciting, because it was a day of walking with your backpack and your GPS and notebook and just picking up anything that might be a fossil. LN: And at some point, she noticed something. NR: Rusty, kind of rust-colored, about the size of the palm of my hand. It was just lying on the surface.

# %%
# Map Korean to Japanese

# !python main.py --model m2m --weights facebook/m2m100_418M --data ko-en --sample 500 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from ko to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped ko to ja
# Mapped ko to ja
# Scored 12.100539807262644 on language pair ko-en.
# 100% 1/1 [01:21<00:00, 81.97s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# ko-en
#
# BLEU
# 12.100539807262644
#
# AVG SPEED
# 1.2806925201416015
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        58.08%        1.741s        58.08%        1.741s      83.857us       0.000us         0.00%       0.000us       0.000us         20758
#                                      aten::index_select         0.62%      18.455ms        53.92%        1.616s       1.007ms     138.106ms        13.94%     138.106ms      86.047us          1605
#                                         aten::embedding         0.01%     414.000us        52.60%        1.576s      47.772ms       0.000us         0.00%     283.000us       8.576us            33
#                                         cudaMemcpyAsync        19.19%     575.000ms        19.19%     575.000ms      74.967us       0.000us         0.00%       0.000us       0.000us          7670
#                                              aten::item         0.22%       6.715ms        18.75%     561.799ms     192.331us       0.000us         0.00%       2.875ms       0.984us          2921
#                               aten::_local_scalar_dense         0.51%      15.225ms        18.53%     555.292ms     190.103us       2.923ms         0.30%       2.923ms       1.001us          2921
#                                        aten::is_nonzero         0.06%       1.651ms        17.17%     514.680ms     598.465us       0.000us         0.00%     862.000us       1.002us           860
#                                            aten::linear         0.66%      19.748ms         7.97%     238.773ms      74.617us       0.000us         0.00%     402.818ms     125.881us          3200
#                                            aten::matmul         0.80%      23.936ms         4.50%     134.945ms      42.170us       0.000us         0.00%     383.435ms     119.823us          3200
#                                             aten::copy_         1.24%      37.075ms         3.63%     108.889ms      18.977us      12.141ms         1.23%      12.141ms       2.116us          5738
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 2.997s
# Self CUDA time total: 990.765ms
#
#
# EXAMPLE
# Src: 이 이야기는 우리가 아는 것을 어떻게 아는지에 대한 이야기 입니다. 이 이야기는 이 여성에 대한 이야기 입니다. 나탈리아 리프친스키. 그녀는 고생물학자입니다. 즉, 그녀는 아주 오래 전에 죽은 것들을 파내는데 전문가입니다. 나탈리아 리프친스키: 네 저를 "죽은 것 박사" 라고 부르기도 해요. 라티프 나사: 그리고 제가 그녀에게 관심이 갔던 것은 그녀가 물건을 파내는 곳 때문입니다. 그녀는 북극권 훨씬 위쪽의 외진 캐나다 툰드라 지역에서 일합니다. 2006년의 어느 여름날에 그녀는 Fyles Leaf Bed 라는 발굴 현장에 있었습니다. 자북극에서 위도로 10도도 떨어지지 않은 곳입니다. 나탈리아: 그랬나요? 전혀 대단한 일이 아니었어요. 왜냐면 하루 종일 배낭에 GPS와 노트북을 들고 화석 같아 보이는 건 전부 주우면서 하루종일 걸어 다녔거든요. 라티프:그리고 어느 순간에 그녀는 무언가 깨닫습니다. 나탈리아: 녹슬었어요, 녹슨 것 같은 색깔에 제 손바닥 만한 물건 이었는데. 땅바닥에 그냥 떨어져 있었어요.
# Pred: This is a story about how we know what we know. This is a story about this woman. by Natalia Rifchinsky. She is a biologist. That is, she’s an expert in removing things that were dead a long time ago. Natalia Rifchinsky: You call me “Doctor of the Dead.” Latiff Nasa: And what I was interested in her was because she was leaving things. She works in the outer Canadian Tundra region far above the Arctic. One summer day in 2006, she was on the mining site called Fyles Leaf Bed. It is not 10 degrees down from the Arctic. Natalia: Did you do it? It was not great at all. Because I had a GPS and a laptop on my backpack all day, and it looked like a fossil, and I was walking all day. Latiff: And at a moment she realizes something. Nathalie: I was crazy, it was something that I could do with my handheld in a color like Nocson. I was just on the ground.
# Ref: So, this is a story about how we know what we know. It's a story about this woman, Natalia Rybczynski. She's a paleobiologist, which means she specializes in digging up really old dead stuff. Natalia Rybczynski: Yeah, I had someone call me "Dr. Dead Things." Latif Nasser: And I think she's particularly interesting because of where she digs that stuff up, way above the Arctic Circle in the remote Canadian tundra. Now, one summer day in 2006, she was at a dig site called the Fyles Leaf Bed, which is less than 10 degrees latitude away from the magnetic north pole. NR: Really, it's not going to sound very exciting, because it was a day of walking with your backpack and your GPS and notebook and just picking up anything that might be a fossil. LN: And at some point, she noticed something. NR: Rusty, kind of rust-colored, about the size of the palm of my hand. It was just lying on the surface.

# %%
# Map Korean to Chinese

# !python main.py --model m2m --weights facebook/m2m100_418M --data ko-en --sample 500 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from ko to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped ko to zh
# Mapped ko to zh
# Scored 12.100539807262644 on language pair ko-en.
# 100% 1/1 [01:22<00:00, 82.02s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# ko-en
#
# BLEU
# 12.100539807262644
#
# AVG SPEED
# 1.2812775993347167
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        58.28%        1.736s        58.28%        1.736s      83.608us       0.000us         0.00%       0.000us       0.000us         20758
#                                      aten::index_select         0.62%      18.323ms        54.11%        1.611s       1.004ms     138.180ms        13.95%     138.180ms      86.093us          1605
#                                         aten::embedding         0.01%     385.000us        52.79%        1.572s      47.630ms       0.000us         0.00%     288.000us       8.727us            33
#                                         cudaMemcpyAsync        19.39%     577.450ms        19.39%     577.450ms      75.287us       0.000us         0.00%       0.000us       0.000us          7670
#                                              aten::item         0.22%       6.500ms        18.92%     563.362ms     192.866us       0.000us         0.00%       2.859ms       0.979us          2921
#                               aten::_local_scalar_dense         0.51%      15.056ms        18.71%     557.142ms     190.737us       2.923ms         0.30%       2.923ms       1.001us          2921
#                                        aten::is_nonzero         0.05%       1.584ms        17.32%     515.623ms     599.562us       0.000us         0.00%     862.000us       1.002us           860
#                                            aten::linear         0.65%      19.270ms         7.77%     231.329ms      72.290us       0.000us         0.00%     401.774ms     125.554us          3200
#                                            aten::matmul         0.78%      23.242ms         4.41%     131.283ms      41.026us       0.000us         0.00%     382.261ms     119.457us          3200
#                                             aten::copy_         1.23%      36.590ms         3.65%     108.705ms      18.945us      12.073ms         1.22%      12.073ms       2.104us          5738
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 2.978s
# Self CUDA time total: 990.319ms
#
#
# EXAMPLE
# Src: 이 이야기는 우리가 아는 것을 어떻게 아는지에 대한 이야기 입니다. 이 이야기는 이 여성에 대한 이야기 입니다. 나탈리아 리프친스키. 그녀는 고생물학자입니다. 즉, 그녀는 아주 오래 전에 죽은 것들을 파내는데 전문가입니다. 나탈리아 리프친스키: 네 저를 "죽은 것 박사" 라고 부르기도 해요. 라티프 나사: 그리고 제가 그녀에게 관심이 갔던 것은 그녀가 물건을 파내는 곳 때문입니다. 그녀는 북극권 훨씬 위쪽의 외진 캐나다 툰드라 지역에서 일합니다. 2006년의 어느 여름날에 그녀는 Fyles Leaf Bed 라는 발굴 현장에 있었습니다. 자북극에서 위도로 10도도 떨어지지 않은 곳입니다. 나탈리아: 그랬나요? 전혀 대단한 일이 아니었어요. 왜냐면 하루 종일 배낭에 GPS와 노트북을 들고 화석 같아 보이는 건 전부 주우면서 하루종일 걸어 다녔거든요. 라티프:그리고 어느 순간에 그녀는 무언가 깨닫습니다. 나탈리아: 녹슬었어요, 녹슨 것 같은 색깔에 제 손바닥 만한 물건 이었는데. 땅바닥에 그냥 떨어져 있었어요.
# Pred: This is a story about how we know what we know. This is a story about this woman. by Natalia Rifchinsky. She is a biologist. That is, she’s an expert in removing things that were dead a long time ago. Natalia Rifchinsky: You call me “Doctor of the Dead.” Latiff Nasa: And what I was interested in her was because she was leaving things. She works in the outer Canadian Tundra region far above the Arctic. One summer day in 2006, she was on the mining site called Fyles Leaf Bed. It is not 10 degrees down from the Arctic. Natalia: Did you do it? It was not great at all. Because I had a GPS and a laptop on my backpack all day, and it looked like a fossil, and I was walking all day. Latiff: And at a moment she realizes something. Nathalie: I was crazy, it was something that I could do with my handheld in a color like Nocson. I was just on the ground.
# Ref: So, this is a story about how we know what we know. It's a story about this woman, Natalia Rybczynski. She's a paleobiologist, which means she specializes in digging up really old dead stuff. Natalia Rybczynski: Yeah, I had someone call me "Dr. Dead Things." Latif Nasser: And I think she's particularly interesting because of where she digs that stuff up, way above the Arctic Circle in the remote Canadian tundra. Now, one summer day in 2006, she was at a dig site called the Fyles Leaf Bed, which is less than 10 degrees latitude away from the magnetic north pole. NR: Really, it's not going to sound very exciting, because it was a day of walking with your backpack and your GPS and notebook and just picking up anything that might be a fossil. LN: And at some point, she noticed something. NR: Rusty, kind of rust-colored, about the size of the palm of my hand. It was just lying on the surface.

# %%
# Map Korean to English

# !python main.py --model m2m --weights facebook/m2m100_418M --data ko-en --sample 500 --mergesents 10
# Out:
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
#   0% 0/1 [00:00<?, ?it/s]Starting translation from ko to en.
# Benchmarking: Source reduced to 50 samples with 10 sentences each.
# Benchmarking: Target reduced to 50 samples with 10 sentences each.
# Mapped ko to en
# Mapped ko to en
# Scored 11.973293742663435 on language pair ko-en.
# 100% 1/1 [01:24<00:00, 84.03s/it]
# MODEL REPORT: facebook/m2m100_418M
# ---------------------------
# ko-en
#
# BLEU
# 11.973293742663435
#
# AVG SPEED
# 1.325267219543457
#
# MEM REPORT
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                        cudaLaunchKernel        58.14%        1.720s        58.14%        1.720s      82.849us       0.000us         0.00%       0.000us       0.000us         20758
#                                      aten::index_select         0.61%      18.047ms        53.99%        1.597s     995.064us     138.228ms        13.94%     138.228ms      86.123us          1605
#                                         aten::embedding         0.01%     402.000us        52.69%        1.559s      47.234ms       0.000us         0.00%     303.000us       9.182us            33
#                                         cudaMemcpyAsync        19.48%     576.379ms        19.48%     576.379ms      75.147us       0.000us         0.00%       0.000us       0.000us          7670
#                                              aten::item         0.21%       6.343ms        19.02%     562.732ms     192.650us       0.000us         0.00%       2.892ms       0.990us          2921
#                               aten::_local_scalar_dense         0.51%      14.967ms        18.82%     556.567ms     190.540us       2.938ms         0.30%       2.938ms       1.006us          2921
#                                        aten::is_nonzero         0.06%       1.650ms        17.43%     515.469ms     599.383us       0.000us         0.00%     869.000us       1.010us           860
#                                            aten::linear         0.64%      18.882ms         7.79%     230.315ms      71.973us       0.000us         0.00%     403.137ms     125.980us          3200
#                                            aten::matmul         0.78%      23.036ms         4.41%     130.525ms      40.789us       0.000us         0.00%     383.807ms     119.940us          3200
#                                             aten::copy_         1.22%      36.085ms         3.64%     107.664ms      18.763us      12.202ms         1.23%      12.202ms       2.127us          5738
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 2.958s
# Self CUDA time total: 991.364ms
#
#
# EXAMPLE
# Src: 이 이야기는 우리가 아는 것을 어떻게 아는지에 대한 이야기 입니다. 이 이야기는 이 여성에 대한 이야기 입니다. 나탈리아 리프친스키. 그녀는 고생물학자입니다. 즉, 그녀는 아주 오래 전에 죽은 것들을 파내는데 전문가입니다. 나탈리아 리프친스키: 네 저를 "죽은 것 박사" 라고 부르기도 해요. 라티프 나사: 그리고 제가 그녀에게 관심이 갔던 것은 그녀가 물건을 파내는 곳 때문입니다. 그녀는 북극권 훨씬 위쪽의 외진 캐나다 툰드라 지역에서 일합니다. 2006년의 어느 여름날에 그녀는 Fyles Leaf Bed 라는 발굴 현장에 있었습니다. 자북극에서 위도로 10도도 떨어지지 않은 곳입니다. 나탈리아: 그랬나요? 전혀 대단한 일이 아니었어요. 왜냐면 하루 종일 배낭에 GPS와 노트북을 들고 화석 같아 보이는 건 전부 주우면서 하루종일 걸어 다녔거든요. 라티프:그리고 어느 순간에 그녀는 무언가 깨닫습니다. 나탈리아: 녹슬었어요, 녹슨 것 같은 색깔에 제 손바닥 만한 물건 이었는데. 땅바닥에 그냥 떨어져 있었어요.
# Pred: This is a story about how we know what we know. This is a story about this woman. by Natalia Rifchinsky. She is a biologist. That is, she’s an expert in removing things that were dead a long time ago. Natalia Rifchinsky: You call me “Doctor of the Dead.” Latiff Nasa: And what I was interested in her was because she was leaving things. She works in the outer Canadian Tundra region far above the Arctic. One summer day in 2006, she was on the mining site called Fyles Leaf Bed. It is not 10 degrees down from the Arctic. Natalia: Did you do it? It was not great at all. Because I had a GPS and a laptop on my backpack all day, and it looked like a fossil, and I was walking all day. Latiff: And at a moment she realizes something. Nathalie: I was crazy, it was something that I could do with my handheld in a color like Nocson. I was just on the ground.
# Ref: So, this is a story about how we know what we know. It's a story about this woman, Natalia Rybczynski. She's a paleobiologist, which means she specializes in digging up really old dead stuff. Natalia Rybczynski: Yeah, I had someone call me "Dr. Dead Things." Latif Nasser: And I think she's particularly interesting because of where she digs that stuff up, way above the Arctic Circle in the remote Canadian tundra. Now, one summer day in 2006, she was at a dig site called the Fyles Leaf Bed, which is less than 10 degrees latitude away from the magnetic north pole. NR: Really, it's not going to sound very exciting, because it was a day of walking with your backpack and your GPS and notebook and just picking up anything that might be a fossil. LN: And at some point, she noticed something. NR: Rusty, kind of rust-colored, about the size of the palm of my hand. It was just lying on the surface.
